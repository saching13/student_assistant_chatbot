# %% [markdown]
# # Building a Conversational Chatbot for Slack using Rasa and Python -Part 1

# %% [markdown]
# ## Starting Jupyter Notebook with necessary imports

# %%
# %matplotlib inline

import logging, io, json, warnings
logging.basicConfig(level="INFO")
warnings.filterwarnings('ignore')

# %% [markdown]
# # Installations
# * Rasa NLU
# * Rasa Core
# * SpaCy Language Model

# %%
import sys
python = sys.executable

# In your environment run:
# !{python} -m pip install -U rasa_core==0.9.6 rasa_nlu[spacy];
# Out:
# Collecting rasa_core==0.9.6
#   Using cached https://files.pythonhosted.org/packages/72/de/82e762685a991351a9f89d934b1b25fe04d10462cf4017f93227cb4d9058/rasa_core-0.9.6-py2.py3-none-any.whl
# Collecting rasa_nlu[spacy]
#   Using cached https://files.pythonhosted.org/packages/d6/53/31b6b14e124fa916c10e8e58d650cff57ace0027a9e69a0788b1afcc26f4/rasa_nlu-0.14.6-py2.py3-none-any.whl
# Collecting python-telegram-bot~=10.0 (from rasa_core==0.9.6)
#   Using cached https://files.pythonhosted.org/packages/f1/51/d1bd383522c12b313eddd7b97b8e7d6cd2a8e3b44b8ff3c88e4a7b045cc8/python_telegram_bot-10.1.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: coloredlogs~=10.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (10.0)
# Requirement already satisfied, skipping upgrade: ConfigArgParse~=0.13.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (0.13.0)
# Requirement already satisfied, skipping upgrade: graphviz~=0.8.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (0.8.4)
# Requirement already satisfied, skipping upgrade: requests~=2.15 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (2.21.0)
# Requirement already satisfied, skipping upgrade: mattermostwrapper~=2.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (2.1)
# Requirement already satisfied, skipping upgrade: fbmessenger~=5.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (5.4.0)
# Requirement already satisfied, skipping upgrade: flask-cors~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (3.0.7)
# Requirement already satisfied, skipping upgrade: ruamel.yaml~=0.15.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (0.15.89)
# Collecting tensorflow<1.9,>=1.7 (from rasa_core==0.9.6)
#   Using cached https://files.pythonhosted.org/packages/03/ad/d732a5d9d50bfcd8aeb6e4a266065a8868829388e4e2b529ff689f1fc923/tensorflow-1.8.0-cp36-cp36m-macosx_10_11_x86_64.whl
# ^C
# Operation cancelled by user

# %%
# !{python} -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: en_core_web_md==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz#egg=en_core_web_md==2.0.0 in /usr/local/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /usr/local/lib/python3.6/site-packages/en_core_web_md -->
#     /usr/local/lib/python3.6/site-packages/spacy/data/en_core_web_md
#
#     You can now load the model via spacy.load('en_core_web_md')

# %% [markdown]
# ## Downloading the English Language Model

# %%
# !{python} -m spacy link en_core_web_md en --force;
# Out:
#     Linking successful
#     /usr/local/lib/python3.6/site-packages/en_core_web_md -->
#     /usr/local/lib/python3.6/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')

# %%
# !pip install rasa_core
# Out:
# Requirement already satisfied: rasa_core in /usr/local/lib/python3.6/site-packages (0.13.3)
# Requirement already satisfied: keras-applications==1.0.6 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.6)
# Requirement already satisfied: flask-cors~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.0.7)
# Requirement already satisfied: slackclient~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.3.1)
# Requirement already satisfied: coloredlogs~=10.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (10.0)
# Requirement already satisfied: requests~=2.20 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.21.0)
# Requirement already satisfied: fbmessenger~=5.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (5.4.0)
# Requirement already satisfied: rasa-nlu~=0.14.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.14.4)
# Requirement already satisfied: tqdm~=4.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (4.31.1)
# Requirement already satisfied: packaging~=18.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (18.0)
# Requirement already satisfied: rocketchat-API~=0.6.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.6.27)
# Requirement already satisfied: twilio~=6.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (6.25.1)
# Requirement already satisfied: webexteamssdk~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.1.1)
# Requirement already satisfied: ruamel.yaml~=0.15.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.15.89)
# Requirement already satisfied: gevent~=1.4 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.4.0)
# Requirement already satisfied: python-telegram-bot~=11.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (11.1.0)
# Requirement already satisfied: mattermostwrapper~=2.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.1)
# Requirement already satisfied: rasa-core-sdk~=0.12.1 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.12.2)
# Requirement already satisfied: pymongo~=3.7 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.7.2)
# Requirement already satisfied: jsonschema~=2.6 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.6.0)
# Requirement already satisfied: questionary>=1.0.1 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: tensorflow~=1.12.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.12.0)
# Requirement already satisfied: scipy~=1.2 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.2.1)
# Requirement already satisfied: apscheduler~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.5.3)
# Requirement already satisfied: pydot~=1.4 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.4.1)
# Requirement already satisfied: redis~=2.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.10.6)
# Requirement already satisfied: typing~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.6.6)
# Requirement already satisfied: pykwalify~=1.7.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.7.0)
# Requirement already satisfied: python-socketio~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.1.2)
# Requirement already satisfied: flask-jwt-simple~=0.0.3 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.0.3)
# Requirement already satisfied: scikit-learn~=0.20.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.20.3)
# Requirement already satisfied: pytz~=2018.9 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2018.9)
# Requirement already satisfied: jsonpickle~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.1)
# Requirement already satisfied: python-dateutil~=2.7 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.7.5)
# Requirement already satisfied: flask~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: colorclass~=2.2 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.2.0)
# Requirement already satisfied: networkx~=2.2 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.2)
# Requirement already satisfied: terminaltables~=3.1 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.1.0)
# Requirement already satisfied: fakeredis~=0.10.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.10.3)
# Requirement already satisfied: numpy~=1.16 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.16.2)
# Requirement already satisfied: keras-preprocessing==1.0.5 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.5)
# Requirement already satisfied: colorhash~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: pika~=0.12.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/site-packages (from keras-applications==1.0.6->rasa_core) (2.8.0)
# Requirement already satisfied: Six in /usr/local/lib/python3.6/site-packages (from flask-cors~=3.0->rasa_core) (1.11.0)
# Requirement already satisfied: websocket-client<0.55.0,>=0.35 in /usr/local/lib/python3.6/site-packages (from slackclient~=1.0->rasa_core) (0.54.0)
# Requirement already satisfied: humanfriendly>=4.7 in /usr/local/lib/python3.6/site-packages (from coloredlogs~=10.0->rasa_core) (4.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (1.24.1)
# Requirement already satisfied: matplotlib~=2.0 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (2.2.4)
# Requirement already satisfied: cloudpickle~=0.6.1 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (0.6.1)
# Requirement already satisfied: boto3~=1.5 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (1.9.113)
# Requirement already satisfied: simplejson~=3.13 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (3.16.0)
# Requirement already satisfied: klein~=17.10 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (17.10.0)
# Requirement already satisfied: future~=0.17.1 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (0.17.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/site-packages (from packaging~=18.0->rasa_core) (2.3.0)
# Requirement already satisfied: PyJWT>=1.4.2 in /usr/local/lib/python3.6/site-packages (from twilio~=6.0->rasa_core) (1.7.1)
# Requirement already satisfied: pysocks; python_version >= "3.0" in /usr/local/lib/python3.6/site-packages (from twilio~=6.0->rasa_core) (1.6.8)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.6/site-packages (from webexteamssdk~=1.0->rasa_core) (0.9.1)
# Requirement already satisfied: greenlet>=0.4.14; platform_python_implementation == "CPython" in /usr/local/lib/python3.6/site-packages (from gevent~=1.4->rasa_core) (0.4.15)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.6/site-packages (from python-telegram-bot~=11.0->rasa_core) (2.6.1)
# Requirement already satisfied: ConfigArgParse~=0.13.0 in /usr/local/lib/python3.6/site-packages (from rasa-core-sdk~=0.12.1->rasa_core) (0.13.0)
# Requirement already satisfied: prompt-toolkit~=2.0 in /usr/local/lib/python3.6/site-packages (from questionary>=1.0.1->rasa_core) (2.0.7)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (3.6.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (1.16.1)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (0.6.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (0.7.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (0.2.0)
# Requirement already satisfied: tensorboard<1.13.0,>=1.12.0 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (1.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (0.31.1)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.6/site-packages (from apscheduler~=3.0->rasa_core) (1.5.1)
# Requirement already satisfied: setuptools>=0.7 in /usr/local/lib/python3.6/site-packages (from apscheduler~=3.0->rasa_core) (39.2.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/site-packages (from pykwalify~=1.7.0->rasa_core) (3.13)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.6/site-packages (from pykwalify~=1.7.0->rasa_core) (0.6.2)
# Requirement already satisfied: python-engineio>=3.2.0 in /usr/local/lib/python3.6/site-packages (from python-socketio~=3.0->rasa_core) (3.4.3)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (2.10)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (7.0)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (0.14.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/site-packages (from networkx~=2.2->rasa_core) (4.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/site-packages (from matplotlib~=2.0->rasa-nlu~=0.14.0->rasa_core) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/site-packages (from matplotlib~=2.0->rasa-nlu~=0.14.0->rasa_core) (1.0.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.2.0)
# Requirement already satisfied: botocore<1.13.0,>=1.12.113 in /usr/local/lib/python3.6/site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (1.12.113)
# Requirement already satisfied: Twisted>=15.5 in /usr/local/lib/python3.6/site-packages (from klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (18.9.0)
# Requirement already satisfied: incremental in /usr/local/lib/python3.6/site-packages (from klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (17.5.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (1.12.2)
# Requirement already satisfied: asn1crypto>=0.21.0 in /usr/local/lib/python3.6/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (0.24.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/site-packages (from prompt-toolkit~=2.0->questionary>=1.0.1->rasa_core) (0.1.7)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/site-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow~=1.12.0->rasa_core) (3.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/site-packages (from Jinja2>=2.10->flask~=1.0->rasa_core) (1.1.0)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.113->boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.14)
# Requirement already satisfied: Automat>=0.3.0 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (0.7.0)
# Requirement already satisfied: PyHamcrest>=1.9.0 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (1.9.0)
# Requirement already satisfied: zope.interface>=4.4.2 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (4.6.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (19.1.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (18.0.0)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (15.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography->python-telegram-bot~=11.0->rasa_core) (2.19)

# %% [markdown]
# # Importing the Installations

# %%
import rasa_nlu
import rasa_core
import spacy

# %% [markdown]
# # 1. Teaching the bot to understand user inputs using Rasa NLU

# %% [markdown]
# ## Preparing the NLU Training Data

# %% [markdown]
# nlu_md = """
# ## intent:greet
# - hey
# - hello there
# - hi
# - hello there
# - good morning
# - good evening
# - moin
# - hey there
# - let's go
# - hey dude
# - goodmorning
# - goodevening
# - good afternoon
#
# ## intent:goodbye
# - cu
# - good by
# - cee you later
# - good night
# - good afternoon
# - bye
# - goodbye
# - have a nice day
# - see you around
# - bye bye
# - see you later
#
# ## intent:mood_affirm
# - yes
# - indeed
# - of course
# - that sounds good
# - correct
#
# ## intent:mood_deny
# - no
# - never
# - I don't think so
# - don't like that
# - no way
# - not really
#
#
#
#
# ## intent:student_work_authorization
# - What does the student’s work authorization look like?
# - how is student work authorization?
# - how does student work authorization look like?
# - Student work authorization look?
# - what's Student work authorization
#
# ## intent:student_work
# - When can a student work?
# - When can I work?
#
#
# ## intent:student_work_timings
# - How many hours per week can a student work?
# - How many hours can I work?
# - number of hours I can work?
# - no. of hours I can work?
#
# ## intent:taxes
# - Are F-1 students subject to taxes?
# - am I subjected to tax ?
# - how much tax shoud I pay ?
# - should I pay tax ?
#
# ## intent:E_verify
# - What is E-Verify?
# - how to do e-verify?
# - What is E Verify?
# - how to do e verify?
# - What is EVerify?
# - how to do everify
#
# ##intent: Visa_interview
# -What all do I need for Visa Interview?
# -what all documents do I need for Visa Interview?
# -Documents needed for Visa Interview?
# -What all things do I need for Visa Interview?
# -What all papaers do I need for Visa Interview?
#
# ##intent: travel_date
# -When can I travel to the usa?
# -How many days prior to my admission can I travel to the USA?
#
# ## intent:customs_immigration
# -What all do I need for customs and immigration?
# -what all documents do I need for customs and immigration?
# -Documents needed for customs and immigration?
# -What all things do I need for customs and immigration?
# -What all papaers do I need for customs and immigration?
#
# ##intent:questions_during_visa
# -What are the common questions asked during Visa interview?
# -What should I prepare for Visa interview?
# -What kind of questions are asked during a visa interview?
# -Common questions durin Visa interview?
# -Questions asked in a Visa interview?
#
# ##intent:health_insurance
# -How do I pyrchase University heath insurance?
# -What steps are involved in purchasing student health insurance?
# -Steps to purchase health insurance?
# -international Heath Insurance puchase?
#
# ##intent:immunization
# -What are the steps involved in immunization?
# -What all immunization do I need before getting to the USA?
# -Kind of immunization required before reaching?
# -What is the proof of immunization that needs to be submitted?
#
# ##intent:housing
# -Where can I find the housing details of SJSU?
# -Accomodation in SJSU?
# -Accomodation for international students at SJSU?
# -Housing for students near SJSU?
# -Housing on campus?
#
# ##intent:course_registration
# -How many courses do I need to register for?
# -How many credits are mandatory?
# -Number of credits at SJSU?
# -SJSU credits for F1 students?
#
# ##intent:tution
# -Where can I find details about my tution fees?
# -Information about tution fees?
# -When do I have to pay for tution fees?
# -When can I register for the courses?
# -Where do I pay my tution?
#
# ##intent:tower_ID
# -Where can I get my ID?
# -Do I need an ID?
# -Procedure to get an ID?
# -Documents required to get an ID?
# -How do I get my student ID?
# -Steps involved in getting student ID card?
#
# ## intent: inform
# - A [dog](group:shibes)
# - [dog](group:shibes)
# - [bird](group:birds)
# - a [cat](group:cats)
# - [cat](group:cats)
# - a [bird](group:birds)
# - of a [dog](group:shibes)
# - of a [cat](group:cats)
# - a [bird](group:birds), please
# - a [dog](group:shibes), please
# """
#
# %store nlu_md > nlu.md

# %%
# %ls
# Out:
# chatbot_config.py                nlu_model.py
# config.yml                       policy_config.yml
# domain.yml                       slack_connector.py
# errors.json                      stories.md
# models/                          stories_backup.md
# nlu.md                           story_graph.png
# nlu_config.yml                   student_assistant_chatbot.ipynb

# %% [markdown]
# ## Defining the NLU Model Configuration

# %%
config = """
language: "en"

pipeline:
- name: "nlp_spacy"
- name: "tokenizer_spacy"
- name: "intent_entity_featurizer_regex"
- name: "intent_featurizer_spacy"
- name: "ner_crf"
- name: "ner_synonyms"
- name: "intent_classifier_sklearn"
"""

# %store config > nlu_config.yml
# Out:
# Writing 'config' (str) to file 'nlu_config.yml'.

# %%
config = """
language: "en"

pipeline:
- name: "tokenizer_whitespace"
- name: "ner_crf"
- name: "ner_synonyms"
- name: "intent_featurizer_count_vectors"
- name: "intent_classifier_tensorflow_embedding"
- name: "ner_duckling_http"
  url: "http://127.0.0.1:8000"
  dimensions: ["time"] 
"""

# %store config > nlu_config.yml
# Out:
# Writing 'config' (str) to file 'nlu_config.yml'.

# %% [markdown]
# ## Training the NLU Model.

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# loading the nlu training samples
training_data = load_data("nlu.md")

# trainer to educate our pipeline
trainer = Trainer(config.load("nlu_config.yml"))

# train the model!
interpreter = trainer.train(training_data)

# store it for future use
model_directory = trainer.persist("./models/nlu", fixed_model_name="current")
# Out:
# Epochs: 100%|██████████| 300/300 [00:03<00:00, 99.53it/s, loss=0.135, acc=0.990]

# %% [markdown]
# ## Evaluating the NLU model on a random text

# %%
# A helper function for prettier output
import json
def pprint(o):   
    print(json.dumps(o, indent=2))
    
pprint(interpreter.parse("is there any event on day after tomorrow ? "))
# Out:
# {
#   "intent": {
#     "name": "inform",
#     "confidence": 0.9217749834060669
#   },
#   "entities": [
#     {
#       "start": 13,
#       "end": 18,
#       "value": "event",
#       "entity": "events",
#       "confidence": 0.8924925786107403,
#       "extractor": "ner_crf"
#     },
#     {
#       "start": 19,
#       "end": 40,
#       "text": "on day after tomorrow",
#       "value": "2019-04-18T00:00:00.000-07:00",
#       "confidence": 1.0,
#       "additional_info": {
#         "values": [
#           {
#             "value": "2019-04-18T00:00:00.000-07:00",
#             "grain": "day",
#             "type": "value"
#           }
#         ],
#         "value": "2019-04-18T00:00:00.000-07:00",
#         "grain": "day",
#         "type": "value"
#       },
#       "entity": "time",
#       "extractor": "ner_duckling_http"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "inform",
#       "confidence": 0.9217749834060669
#     },
#     {
#       "name": "goodbye",
#       "confidence": 0.23540902137756348
#     },
#     {
#       "name": "student_work",
#       "confidence": 0.1535656750202179
#     },
#     {
#       "name": "mood_deny",
#       "confidence": 0.10397358238697052
#     },
#     {
#       "name": "taxes",
#       "confidence": 0.10274221748113632
#     },
#     {
#       "name": "greet",
#       "confidence": 0.09450532495975494
#     },
#     {
#       "name": "customs_immigration",
#       "confidence": 0.07463298738002777
#     },
#     {
#       "name": "mood_affirm",
#       "confidence": 0.004936873912811279
#     },
#     {
#       "name": "E_verify",
#       "confidence": 0.0023534968495368958
#     },
#     {
#       "name": "health_insurance",
#       "confidence": 0.0
#     }
#   ],
#   "text": "is there any event on day after tomorrow ? "
# }

# %% [markdown]
# ## Evaluating the NLU model on a test data
# (Here we are using the data at hand i.e nlu.md but it isr recommended to use unseen data)

# %%
from rasa_nlu.evaluate import run_evaluation

run_evaluation("nlu.md", model_directory)
# Out:
# INFO:tensorflow:Restoring parameters from /Users/saching12/Desktop/python codes/student_assistant_chatbot/./models/nlu/default/current/intent_classifier_tensorflow_embedding.ckpt
# INFO:tensorflow:Restoring parameters from /Users/saching12/Desktop/python codes/student_assistant_chatbot/./models/nlu/default/current/intent_classifier_tensorflow_embedding.ckpt
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 104 (20 distinct intents)
# 	- Found intents: 'student_work_timings', 'tution', 'questions_during_visa', 'E_verify', 'health_insurance', 'housing', 'student_work', 'greet', 'tower_ID', 'goodbye', 'travel_date', 'inform', 'student_work_authorization', 'course_registration', 'customs_immigration', 'taxes', 'immunization', 'mood_affirm', 'Visa_interview', 'mood_deny'
# 	- entity examples: 3 (1 distinct entities)
# 	- found entities: 'events'
#
# INFO:rasa_nlu.evaluate:Skipping evaluation of ner_duckling_http
# INFO:rasa_nlu.evaluate:Intent evaluation results:
# INFO:rasa_nlu.evaluate:Intent Evaluation: Only considering those 104 examples that have a defined intent out of 104 examples
# INFO:rasa_nlu.evaluate:F1-Score:  0.9903337403337402
# INFO:rasa_nlu.evaluate:Precision: 0.9910714285714286
# INFO:rasa_nlu.evaluate:Accuracy:  0.9903846153846154
# INFO:rasa_nlu.evaluate:Classification report:
#                             precision    recall  f1-score   support
#
#                   E_verify       1.00      1.00      1.00         6
#             Visa_interview       1.00      1.00      1.00         5
#        course_registration       1.00      1.00      1.00         4
#        customs_immigration       1.00      1.00      1.00         5
#                    goodbye       1.00      0.91      0.95        11
#                      greet       0.93      1.00      0.96        13
#           health_insurance       1.00      1.00      1.00         4
#                    housing       1.00      1.00      1.00         5
#               immunization       1.00      1.00      1.00         4
#                     inform       1.00      1.00      1.00         3
#                mood_affirm       1.00      1.00      1.00         5
#                  mood_deny       1.00      1.00      1.00         6
#      questions_during_visa       1.00      1.00      1.00         5
#               student_work       1.00      1.00      1.00         2
# student_work_authorization       1.00      1.00      1.00         5
#       student_work_timings       1.00      1.00      1.00         4
#                      taxes       1.00      1.00      1.00         4
#                   tower_ID       1.00      1.00      1.00         6
#                travel_date       1.00      1.00      1.00         2
#                     tution       1.00      1.00      1.00         5
#
#                  micro avg       0.99      0.99      0.99       104
#                  macro avg       1.00      1.00      1.00       104
#               weighted avg       0.99      0.99      0.99       104
#
# INFO:rasa_nlu.evaluate:Model prediction errors saved to errors.json.
# INFO:rasa_nlu.evaluate:Entity evaluation results:
# INFO:rasa_nlu.evaluate:Evaluation for entity extractor: ner_crf
# INFO:rasa_nlu.evaluate:F1-Score:  1.0
# INFO:rasa_nlu.evaluate:Precision: 1.0
# INFO:rasa_nlu.evaluate:Accuracy:  1.0
# INFO:rasa_nlu.evaluate:Classification report:
#               precision    recall  f1-score   support
#
#       events       1.00      1.00      1.00         3
#    no_entity       1.00      1.00      1.00       514
#
#    micro avg       1.00      1.00      1.00       517
#    macro avg       1.00      1.00      1.00       517
# weighted avg       1.00      1.00      1.00       517
# {'intent_evaluation': {'predictions': [{'text': 'hey',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9697084426879883},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9683195352554321},
#    {'text': 'hi',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9640589952468872},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9683195352554321},
#    {'text': 'good morning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9776124358177185},
#    {'text': 'good evening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9719564318656921},
#    {'text': 'moin',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9577948451042175},
#    {'text': 'hey there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9623345732688904},
#    {'text': "let's go",
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9815815687179565},
#    {'text': 'hey dude',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9782136678695679},
#    {'text': 'good morning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9776124358177185},
#    {'text': 'good evening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9719564318656921},
#    {'text': 'good afternoon',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.7381491661071777},
#    {'text': 'cu',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.924860954284668},
#    {'text': 'good by',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9245909452438354},
#    {'text': 'cee you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9654041528701782},
#    {'text': 'good night',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9531242251396179},
#    {'text': 'good afternoon',
#     'intent': 'goodbye',
#     'predicted': 'greet',
#     'confidence': 0.7381491661071777},
#    {'text': 'bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9360664486885071},
#    {'text': 'goodbye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9208492040634155},
#    {'text': 'have a nice day',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9476683735847473},
#    {'text': 'see you around',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9613560438156128},
#    {'text': 'bye bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9586060047149658},
#    {'text': 'see you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9674496054649353},
#    {'text': 'yes',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.935373067855835},
#    {'text': 'indeed',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9210599064826965},
#    {'text': 'of course',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9109625220298767},
#    {'text': 'that sounds good',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9416934847831726},
#    {'text': 'correct',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9367388486862183},
#    {'text': 'no',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.942272424697876},
#    {'text': 'never',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9286998510360718},
#    {'text': "I don't think so",
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9485076665878296},
#    {'text': "don't like that",
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9633979797363281},
#    {'text': 'no way',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.941922664642334},
#    {'text': 'not really',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9412391185760498},
#    {'text': 'What does the student’s work authorization look like?',
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9741086959838867},
#    {'text': 'how is student work authorization?',
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9720228314399719},
#    {'text': 'how does student work authorization look like?',
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9781456589698792},
#    {'text': 'Student work authorization look?',
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9799925088882446},
#    {'text': "what's Student work authorization",
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9749875068664551},
#    {'text': 'When can a student work?',
#     'intent': 'student_work',
#     'predicted': 'student_work',
#     'confidence': 0.9576306939125061},
#    {'text': 'When can I work?',
#     'intent': 'student_work',
#     'predicted': 'student_work',
#     'confidence': 0.9569044709205627},
#    {'text': 'How many hours per week can a student work?',
#     'intent': 'student_work_timings',
#     'predicted': 'student_work_timings',
#     'confidence': 0.9469345211982727},
#    {'text': 'How many hours can I work?',
#     'intent': 'student_work_timings',
#     'predicted': 'student_work_timings',
#     'confidence': 0.9496782422065735},
#    {'text': 'number of hours I can work?',
#     'intent': 'student_work_timings',
#     'predicted': 'student_work_timings',
#     'confidence': 0.951732337474823},
#    {'text': 'no. of hours I can work?',
#     'intent': 'student_work_timings',
#     'predicted': 'student_work_timings',
#     'confidence': 0.9641115665435791},
#    {'text': 'Are F-1 students subject to taxes?',
#     'intent': 'taxes',
#     'predicted': 'taxes',
#     'confidence': 0.9281023144721985},
#    {'text': 'am I subjected to tax ?',
#     'intent': 'taxes',
#     'predicted': 'taxes',
#     'confidence': 0.9340642690658569},
#    {'text': 'how much tax shoud I pay ?',
#     'intent': 'taxes',
#     'predicted': 'taxes',
#     'confidence': 0.948839008808136},
#    {'text': 'should I pay tax ?',
#     'intent': 'taxes',
#     'predicted': 'taxes',
#     'confidence': 0.9213594198226929},
#    {'text': 'What is E-Verify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9428467750549316},
#    {'text': 'how to do e-verify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9454026222229004},
#    {'text': 'What is E Verify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9428467750549316},
#    {'text': 'how to do e verify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9454026222229004},
#    {'text': 'What is EVerify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.955499529838562},
#    {'text': 'how to do everify',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9474855065345764},
#    {'text': 'What all do I need for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9515243172645569},
#    {'text': 'what all documents do I need for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9573076963424683},
#    {'text': 'Documents needed for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9549334645271301},
#    {'text': 'What all things do I need for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9537105560302734},
#    {'text': 'What all papaers do I need for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9537184834480286},
#    {'text': 'When can I travel to the usa?',
#     'intent': 'travel_date',
#     'predicted': 'travel_date',
#     'confidence': 0.9667178392410278},
#    {'text': 'How many days prior to my admission can I travel to the USA?',
#     'intent': 'travel_date',
#     'predicted': 'travel_date',
#     'confidence': 0.9568054676055908},
#    {'text': 'What all do I need for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9371835589408875},
#    {'text': 'what all documents do I need for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9409178495407104},
#    {'text': 'Documents needed for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9382894039154053},
#    {'text': 'What all things do I need for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9427186250686646},
#    {'text': 'What all papaers do I need for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9392043948173523},
#    {'text': 'What are the common questions asked during Visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9628332853317261},
#    {'text': 'What should I prepare for Visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9511817693710327},
#    {'text': 'What kind of questions are asked during a visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9435924291610718},
#    {'text': 'Common questions durin Visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9580684900283813},
#    {'text': 'Questions asked in a Visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9454033970832825},
#    {'text': 'How do I pyrchase University heath insurance?',
#     'intent': 'health_insurance',
#     'predicted': 'health_insurance',
#     'confidence': 0.9390663504600525},
#    {'text': 'What steps are involved in purchasing student health insurance?',
#     'intent': 'health_insurance',
#     'predicted': 'health_insurance',
#     'confidence': 0.934541642665863},
#    {'text': 'Steps to purchase health insurance?',
#     'intent': 'health_insurance',
#     'predicted': 'health_insurance',
#     'confidence': 0.9517495632171631},
#    {'text': 'international Heath Insurance puchase?',
#     'intent': 'health_insurance',
#     'predicted': 'health_insurance',
#     'confidence': 0.9514526128768921},
#    {'text': 'What are the steps involved in immunization?',
#     'intent': 'immunization',
#     'predicted': 'immunization',
#     'confidence': 0.9441537857055664},
#    {'text': 'What all immunization do I need before getting to the USA?',
#     'intent': 'immunization',
#     'predicted': 'immunization',
#     'confidence': 0.9523351192474365},
#    {'text': 'Kind of immunization required before reaching?',
#     'intent': 'immunization',
#     'predicted': 'immunization',
#     'confidence': 0.94636470079422},
#    {'text': 'What is the proof of immunization that needs to be submitted?',
#     'intent': 'immunization',
#     'predicted': 'immunization',
#     'confidence': 0.9426171779632568},
#    {'text': 'Where can I find the housing details of SJSU?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9414016008377075},
#    {'text': 'Accomodation in SJSU?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9434261918067932},
#    {'text': 'Accomodation for international students at SJSU?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9508339762687683},
#    {'text': 'Housing for students near SJSU?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9519358277320862},
#    {'text': 'Housing on campus?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9769699573516846},
#    {'text': 'How many courses do I need to register for?',
#     'intent': 'course_registration',
#     'predicted': 'course_registration',
#     'confidence': 0.9317573308944702},
#    {'text': 'How many credits are mandatory?',
#     'intent': 'course_registration',
#     'predicted': 'course_registration',
#     'confidence': 0.9363347291946411},
#    {'text': 'Number of credits at SJSU?',
#     'intent': 'course_registration',
#     'predicted': 'course_registration',
#     'confidence': 0.9449101686477661},
#    {'text': 'SJSU credits for F1 students?',
#     'intent': 'course_registration',
#     'predicted': 'course_registration',
#     'confidence': 0.9343407154083252},
#    {'text': 'Where can I find details about my tution fees?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9624543190002441},
#    {'text': 'Information about tution fees?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9703822135925293},
#    {'text': 'When do I have to pay for tution fees?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9616786241531372},
#    {'text': 'When can I register for the courses?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9653586745262146},
#    {'text': 'Where do I pay my tution?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9612732529640198},
#    {'text': 'Where can I get my ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9561234712600708},
#    {'text': 'Do I need an ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9675769805908203},
#    {'text': 'Procedure to get an ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9622594118118286},
#    {'text': 'Documents required to get an ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.962833046913147},
#    {'text': 'How do I get my student ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9522407650947571},
#    {'text': 'Steps involved in getting student ID card?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9468299150466919},
#    {'text': 'what event is happening tomorrow?',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9502518177032471},
#    {'text': 'do we have any event today?',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9203757047653198},
#    {'text': 'is there any event on 12th October?',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9439394474029541}],
#   'report': '                            precision    recall  f1-score   support\n\n                  E_verify       1.00      1.00      1.00         6\n            Visa_interview       1.00      1.00      1.00         5\n       course_registration       1.00      1.00      1.00         4\n       customs_immigration       1.00      1.00      1.00         5\n                   goodbye       1.00      0.91      0.95        11\n                     greet       0.93      1.00      0.96        13\n          health_insurance       1.00      1.00      1.00         4\n                   housing       1.00      1.00      1.00         5\n              immunization       1.00      1.00      1.00         4\n                    inform       1.00      1.00      1.00         3\n               mood_affirm       1.00      1.00      1.00         5\n                 mood_deny       1.00      1.00      1.00         6\n     questions_during_visa       1.00      1.00      1.00         5\n              student_work       1.00      1.00      1.00         2\nstudent_work_authorization       1.00      1.00      1.00         5\n      student_work_timings       1.00      1.00      1.00         4\n                     taxes       1.00      1.00      1.00         4\n                  tower_ID       1.00      1.00      1.00         6\n               travel_date       1.00      1.00      1.00         2\n                    tution       1.00      1.00      1.00         5\n\n                 micro avg       0.99      0.99      0.99       104\n                 macro avg       1.00      1.00      1.00       104\n              weighted avg       0.99      0.99      0.99       104\n',
#   'precision': 0.9910714285714286,
#   'f1_score': 0.9903337403337402,
#   'accuracy': 0.9903846153846154},
#  'entity_evaluation': {'ner_crf': {'report': '              precision    recall  f1-score   support\n\n      events       1.00      1.00      1.00         3\n   no_entity       1.00      1.00      1.00       514\n\n   micro avg       1.00      1.00      1.00       517\n   macro avg       1.00      1.00      1.00       517\nweighted avg       1.00      1.00      1.00       517\n',
#    'precision': 1.0,
#    'f1_score': 1.0,
#    'accuracy': 1.0}}}

# %% [markdown]
# # 2. Teaching the bot to respond using Rasa Core

# %% [markdown]
# ## Custom Actions

# %%
from rasa_core.actions import Action
from rasa_core.events import SlotSet
from IPython.core.display import Image, display

import requests

class Action_retrieve_event(Action):
    def name(self):
        return "action_retrieve_event"

    def run(self, dispatcher, tracker, domain):
        
        time = tracker.get_slot('time')
        #date = time.split('T')[0]
        #print("in custom chatbot")
        #r = requests.get('http://shibe.online/api/{}?count=1&urls=true&httpsUrls=true'.format(time))
        #response = r.content.decode()
        #response = response.replace('["',"")
        #response = response.replace('"]',"")
   
        
        #display(Image(response[0], height=550, width=520))
        dispatcher.utter_message("Here is something to cheer you up: ")
        
        return []

# %% [markdown]
# ##  Visualising the Training Data

# %% [markdown]
# ## Install these packages
# !apt-get -qq install -y graphviz libgraphviz-dev pkg-config;
# !breq install graphviz
#
# !{python} -m pip install pygraphviz;

# %%
from IPython.display import Image
from rasa_core.agent import Agent

agent = Agent('domain.yml')
agent.visualize("stories.md", "story_graph.png", max_history=2)
#Image(filename="story_graph.png")
# Out:
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 1091.99it/s, # trackers=1]

# %%
config = """
policies:
  - name: "KerasPolicy"
    epochs: 700
    featurizer:
    - name: MaxHistoryTrackerFeaturizer
      max_history: 2
      state_featurizer:
        - name: BinarySingleStateFeaturizer
  - name: "MemoizationPolicy"
    max_history: 2
  - name: "FallbackPolicy"
    nlu_threshold: 0.5
    core_threshold: 0.2
    fallback_action_name: "utter_unclear"
""" 

# %store config > policy_config.yml
# Out:
# Writing 'config' (str) to file 'policy_config.yml'.

# %% [markdown]
# ## Training a Dialogue Model

# %%
from rasa_core.policies import FallbackPolicy, KerasPolicy, MemoizationPolicy
from rasa_core.agent import Agent
from rasa_core import config


agent = Agent('domain.yml', policies=config.load('policy_config.yml'))

# loading our neatly defined training dialogues
training_data = agent.load_data('stories.md')

agent.train(training_data)
agent.persist('models/dialogue')
# Out:
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 1100.44it/s, # trackers=1]
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 506.30it/s, # trackers=5]
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 460.07it/s, # trackers=5]
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 475.17it/s, # trackers=4]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 2, 57)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                11520
# _________________________________________________________________
# dense (Dense)                (None, 31)                1023
# _________________________________________________________________
# activation (Activation)      (None, 31)                0
# =================================================================
# Total params: 12,543
# Trainable params: 12,543
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/700
# 221/221 [==============================] - 1s 3ms/step - loss: 3.4285 - acc: 0.0181
# Epoch 2/700
# 221/221 [==============================] - 0s 115us/step - loss: 3.4015 - acc: 0.0769
# Epoch 3/700
# 221/221 [==============================] - 0s 112us/step - loss: 3.3780 - acc: 0.1131
# Epoch 4/700
# 221/221 [==============================] - 0s 112us/step - loss: 3.3595 - acc: 0.1086
# Epoch 5/700
# 221/221 [==============================] - 0s 110us/step - loss: 3.3403 - acc: 0.1357
# Epoch 6/700
# 221/221 [==============================] - 0s 111us/step - loss: 3.3167 - acc: 0.1357
# Epoch 7/700
# 221/221 [==============================] - 0s 107us/step - loss: 3.2942 - acc: 0.1312
# Epoch 8/700
# 221/221 [==============================] - 0s 106us/step - loss: 3.2724 - acc: 0.1448
# Epoch 9/700
# 221/221 [==============================] - 0s 109us/step - loss: 3.2397 - acc: 0.1357
# Epoch 10/700
# 221/221 [==============================] - 0s 111us/step - loss: 3.2192 - acc: 0.1267
# Epoch 11/700
# 221/221 [==============================] - 0s 110us/step - loss: 3.1909 - acc: 0.1312
# Epoch 12/700
# 221/221 [==============================] - 0s 111us/step - loss: 3.1638 - acc: 0.1267
# Epoch 13/700
# 221/221 [==============================] - 0s 108us/step - loss: 3.1311 - acc: 0.1403
# Epoch 14/700
# 221/221 [==============================] - 0s 107us/step - loss: 3.0959 - acc: 0.1357
# Epoch 15/700
# 221/221 [==============================] - 0s 110us/step - loss: 3.0728 - acc: 0.1312
# Epoch 16/700
# 221/221 [==============================] - 0s 111us/step - loss: 3.0380 - acc: 0.1403
# Epoch 17/700
# 221/221 [==============================] - 0s 115us/step - loss: 2.9989 - acc: 0.1403
# Epoch 18/700
# 221/221 [==============================] - 0s 116us/step - loss: 2.9697 - acc: 0.1403
# Epoch 19/700
# 221/221 [==============================] - 0s 110us/step - loss: 2.9416 - acc: 0.1403
# Epoch 20/700
# 221/221 [==============================] - 0s 114us/step - loss: 2.9075 - acc: 0.1357
# Epoch 21/700
# 221/221 [==============================] - 0s 110us/step - loss: 2.8868 - acc: 0.1448
# Epoch 22/700
# 221/221 [==============================] - 0s 112us/step - loss: 2.8569 - acc: 0.1538
# Epoch 23/700
# 221/221 [==============================] - 0s 109us/step - loss: 2.8172 - acc: 0.1855
# Epoch 24/700
# 221/221 [==============================] - 0s 113us/step - loss: 2.7961 - acc: 0.1810
# Epoch 25/700
# 221/221 [==============================] - 0s 114us/step - loss: 2.7794 - acc: 0.1855
# Epoch 26/700
# 221/221 [==============================] - 0s 151us/step - loss: 2.7285 - acc: 0.2127
# Epoch 27/700
# 221/221 [==============================] - 0s 121us/step - loss: 2.7207 - acc: 0.2081
# Epoch 28/700
# 221/221 [==============================] - 0s 108us/step - loss: 2.6814 - acc: 0.2353
# Epoch 29/700
# 221/221 [==============================] - 0s 118us/step - loss: 2.6524 - acc: 0.2262
# Epoch 30/700
# 221/221 [==============================] - 0s 111us/step - loss: 2.6402 - acc: 0.2398
# Epoch 31/700
# 221/221 [==============================] - 0s 112us/step - loss: 2.6083 - acc: 0.2262
# Epoch 32/700
# 221/221 [==============================] - 0s 109us/step - loss: 2.5760 - acc: 0.2308
# Epoch 33/700
# 221/221 [==============================] - 0s 119us/step - loss: 2.5777 - acc: 0.2353
# Epoch 34/700
# 221/221 [==============================] - 0s 114us/step - loss: 2.5247 - acc: 0.2443
# Epoch 35/700
# 221/221 [==============================] - 0s 115us/step - loss: 2.5035 - acc: 0.2398
# Epoch 36/700
# 221/221 [==============================] - 0s 114us/step - loss: 2.4615 - acc: 0.2534
# Epoch 37/700
# 221/221 [==============================] - 0s 112us/step - loss: 2.4297 - acc: 0.2489
# Epoch 38/700
# 221/221 [==============================] - 0s 111us/step - loss: 2.4152 - acc: 0.2760
# Epoch 39/700
# 221/221 [==============================] - 0s 108us/step - loss: 2.3748 - acc: 0.2715
# Epoch 40/700
# 221/221 [==============================] - 0s 111us/step - loss: 2.3549 - acc: 0.3122
# Epoch 41/700
# 221/221 [==============================] - 0s 112us/step - loss: 2.2943 - acc: 0.3122
# Epoch 42/700
# 221/221 [==============================] - 0s 121us/step - loss: 2.2375 - acc: 0.3348
# Epoch 43/700
# 221/221 [==============================] - 0s 108us/step - loss: 2.2407 - acc: 0.3303
# Epoch 44/700
# 221/221 [==============================] - 0s 118us/step - loss: 2.1676 - acc: 0.3575
# Epoch 45/700
# 221/221 [==============================] - 0s 110us/step - loss: 2.1430 - acc: 0.3846
# Epoch 46/700
# 221/221 [==============================] - 0s 111us/step - loss: 2.0891 - acc: 0.4299
# Epoch 47/700
# 221/221 [==============================] - 0s 109us/step - loss: 2.0279 - acc: 0.4796
# Epoch 48/700
# 221/221 [==============================] - 0s 114us/step - loss: 1.9635 - acc: 0.5113
# Epoch 49/700
# 221/221 [==============================] - 0s 109us/step - loss: 1.9684 - acc: 0.5792
# Epoch 50/700
# 221/221 [==============================] - 0s 115us/step - loss: 1.8949 - acc: 0.5837
# Epoch 51/700
# 221/221 [==============================] - 0s 112us/step - loss: 1.8397 - acc: 0.6154
# Epoch 52/700
# 221/221 [==============================] - 0s 113us/step - loss: 1.7803 - acc: 0.7240
# Epoch 53/700
# 221/221 [==============================] - 0s 114us/step - loss: 1.7331 - acc: 0.6878
# Epoch 54/700
# 221/221 [==============================] - 0s 118us/step - loss: 1.6740 - acc: 0.7557
# Epoch 55/700
# 221/221 [==============================] - 0s 111us/step - loss: 1.6438 - acc: 0.7738
# Epoch 56/700
# 221/221 [==============================] - 0s 116us/step - loss: 1.6337 - acc: 0.7511
# Epoch 57/700
# 221/221 [==============================] - 0s 111us/step - loss: 1.5596 - acc: 0.8009
# Epoch 58/700
# 221/221 [==============================] - 0s 107us/step - loss: 1.4739 - acc: 0.8190
# Epoch 59/700
# 221/221 [==============================] - 0s 114us/step - loss: 1.4569 - acc: 0.8009
# Epoch 60/700
# 221/221 [==============================] - 0s 119us/step - loss: 1.4310 - acc: 0.8326
# Epoch 61/700
# 221/221 [==============================] - 0s 119us/step - loss: 1.3955 - acc: 0.8009
# Epoch 62/700
# 221/221 [==============================] - 0s 122us/step - loss: 1.3962 - acc: 0.8190
# Epoch 63/700
# 221/221 [==============================] - 0s 113us/step - loss: 1.2902 - acc: 0.8145
# Epoch 64/700
# 221/221 [==============================] - 0s 115us/step - loss: 1.3054 - acc: 0.7919
# Epoch 65/700
# 221/221 [==============================] - 0s 121us/step - loss: 1.2191 - acc: 0.8371
# Epoch 66/700
# 221/221 [==============================] - 0s 120us/step - loss: 1.2402 - acc: 0.8326
# Epoch 67/700
# 221/221 [==============================] - 0s 105us/step - loss: 1.2231 - acc: 0.8054
# Epoch 68/700
# 221/221 [==============================] - 0s 111us/step - loss: 1.0529 - acc: 0.8824
# Epoch 69/700
# 221/221 [==============================] - 0s 115us/step - loss: 1.0130 - acc: 0.8869
# Epoch 70/700
# 221/221 [==============================] - 0s 131us/step - loss: 1.0625 - acc: 0.8371
# Epoch 71/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.9996 - acc: 0.8416
# Epoch 72/700
# 221/221 [==============================] - 0s 111us/step - loss: 1.0546 - acc: 0.8235
# Epoch 73/700
# 221/221 [==============================] - 0s 127us/step - loss: 0.9179 - acc: 0.8733
# Epoch 74/700
# 221/221 [==============================] - 0s 101us/step - loss: 0.9516 - acc: 0.8281
# Epoch 75/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.9573 - acc: 0.8281
# Epoch 76/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.9984 - acc: 0.8100
# Epoch 77/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.8629 - acc: 0.8462
# Epoch 78/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.8449 - acc: 0.8507
# Epoch 79/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.8180 - acc: 0.8643
# Epoch 80/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.9178 - acc: 0.8100
# Epoch 81/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.8585 - acc: 0.8281
# Epoch 82/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.8223 - acc: 0.8462
# Epoch 83/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.7588 - acc: 0.8688
# Epoch 84/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.8570 - acc: 0.8190
# Epoch 85/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.7170 - acc: 0.8552
# Epoch 86/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.7327 - acc: 0.8507
# Epoch 87/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.8010 - acc: 0.8326
# Epoch 88/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.6838 - acc: 0.8733
# Epoch 89/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.6938 - acc: 0.8643
# Epoch 90/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.6418 - acc: 0.8778
# Epoch 91/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.6569 - acc: 0.8643
# Epoch 92/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.6785 - acc: 0.8371
# Epoch 93/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.7319 - acc: 0.8235
# Epoch 94/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.6476 - acc: 0.8643
# Epoch 95/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.5986 - acc: 0.8597
# Epoch 96/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.6609 - acc: 0.8371
# Epoch 97/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.6284 - acc: 0.8552
# Epoch 98/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.5429 - acc: 0.8778
# Epoch 99/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.5500 - acc: 0.8824
# Epoch 100/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.5723 - acc: 0.8914
# Epoch 101/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.5536 - acc: 0.8597
# Epoch 102/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.5936 - acc: 0.8643
# Epoch 103/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.5495 - acc: 0.8733
# Epoch 104/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.6841 - acc: 0.8371
# Epoch 105/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.6366 - acc: 0.8597
# Epoch 106/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.5266 - acc: 0.8824
# Epoch 107/700
# 221/221 [==============================] - 0s 123us/step - loss: 0.4851 - acc: 0.9050
# Epoch 108/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.5958 - acc: 0.8462
# Epoch 109/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.5769 - acc: 0.8597
# Epoch 110/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.5161 - acc: 0.8643
# Epoch 111/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.4967 - acc: 0.8733
# Epoch 112/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.6100 - acc: 0.8416
# Epoch 113/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.5439 - acc: 0.8733
# Epoch 114/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.4580 - acc: 0.8869
# Epoch 115/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.5589 - acc: 0.8552
# Epoch 116/700
# 221/221 [==============================] - 0s 120us/step - loss: 0.5895 - acc: 0.8733
# Epoch 117/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.5900 - acc: 0.8416
# Epoch 118/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.5307 - acc: 0.8552
# Epoch 119/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.5903 - acc: 0.8552
# Epoch 120/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.4707 - acc: 0.8914
# Epoch 121/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.4755 - acc: 0.8778
# Epoch 122/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.5235 - acc: 0.8733
# Epoch 123/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.5250 - acc: 0.8688
# Epoch 124/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.4548 - acc: 0.8914
# Epoch 125/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.6198 - acc: 0.8371
# Epoch 126/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.5829 - acc: 0.8235
# Epoch 127/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.4431 - acc: 0.9005
# Epoch 128/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.4923 - acc: 0.8914
# Epoch 129/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.4025 - acc: 0.9231
# Epoch 130/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.4217 - acc: 0.9005
# Epoch 131/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.6490 - acc: 0.8326
# Epoch 132/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.3867 - acc: 0.9231
# Epoch 133/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.5840 - acc: 0.8326
# Epoch 134/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.4287 - acc: 0.9140
# Epoch 135/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.5483 - acc: 0.8688
# Epoch 136/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.4175 - acc: 0.8959
# Epoch 137/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.3950 - acc: 0.9005
# Epoch 138/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.4223 - acc: 0.9095
# Epoch 139/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.5645 - acc: 0.8371
# Epoch 140/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.4533 - acc: 0.8914
# Epoch 141/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.4544 - acc: 0.9005
# Epoch 142/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.5225 - acc: 0.8688
# Epoch 143/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.5472 - acc: 0.8733
# Epoch 144/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.4281 - acc: 0.9140
# Epoch 145/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.3939 - acc: 0.8869
# Epoch 146/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.3873 - acc: 0.9276
# Epoch 147/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.4392 - acc: 0.9095
# Epoch 148/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.4255 - acc: 0.9140
# Epoch 149/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.5470 - acc: 0.8778
# Epoch 150/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.4381 - acc: 0.8914
# Epoch 151/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.5711 - acc: 0.8733
# Epoch 152/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.5079 - acc: 0.8869
# Epoch 153/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.5838 - acc: 0.8597
# Epoch 154/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.6197 - acc: 0.8552
# Epoch 155/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.3918 - acc: 0.9231
# Epoch 156/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.5229 - acc: 0.8869
# Epoch 157/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.4763 - acc: 0.8914
# Epoch 158/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.5973 - acc: 0.8643
# Epoch 159/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.4397 - acc: 0.9095
# Epoch 160/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.4138 - acc: 0.9005
# Epoch 161/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.3669 - acc: 0.9140
# Epoch 162/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.4548 - acc: 0.9050
# Epoch 163/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.5066 - acc: 0.8869
# Epoch 164/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.4971 - acc: 0.9050
# Epoch 165/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.4288 - acc: 0.9095
# Epoch 166/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.3705 - acc: 0.9276
# Epoch 167/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.4487 - acc: 0.8914
# Epoch 168/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.3923 - acc: 0.9186
# Epoch 169/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.3371 - acc: 0.9548
# Epoch 170/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.4007 - acc: 0.8959
# Epoch 171/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.4376 - acc: 0.8959
# Epoch 172/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.4796 - acc: 0.9050
# Epoch 173/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.5002 - acc: 0.8824
# Epoch 174/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.4654 - acc: 0.9005
# Epoch 175/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.4542 - acc: 0.8914
# Epoch 176/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.4162 - acc: 0.9140
# Epoch 177/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.4285 - acc: 0.9186
# Epoch 178/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.5132 - acc: 0.8959
# Epoch 179/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.3770 - acc: 0.9186
# Epoch 180/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.4038 - acc: 0.9140
# Epoch 181/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.3713 - acc: 0.9095
# Epoch 182/700
# 221/221 [==============================] - 0s 122us/step - loss: 0.3157 - acc: 0.9367
# Epoch 183/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3680 - acc: 0.9140
# Epoch 184/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.4103 - acc: 0.9050
# Epoch 185/700
# 221/221 [==============================] - 0s 104us/step - loss: 0.3986 - acc: 0.9095
# Epoch 186/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.4588 - acc: 0.8914
# Epoch 187/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.4722 - acc: 0.8869
# Epoch 188/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.3500 - acc: 0.9276
# Epoch 189/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.2941 - acc: 0.9593
# Epoch 190/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.2889 - acc: 0.9412
# Epoch 191/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.3829 - acc: 0.9186
# Epoch 192/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3809 - acc: 0.9186
# Epoch 193/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.4307 - acc: 0.9140
# Epoch 194/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.3713 - acc: 0.9367
# Epoch 195/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.4293 - acc: 0.9321
# Epoch 196/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.3682 - acc: 0.9276
# Epoch 197/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3675 - acc: 0.9186
# Epoch 198/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.3528 - acc: 0.9548
# Epoch 199/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.3272 - acc: 0.9367
# Epoch 200/700
# 221/221 [==============================] - 0s 122us/step - loss: 0.4675 - acc: 0.9186
# Epoch 201/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.3677 - acc: 0.9367
# Epoch 202/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.3247 - acc: 0.9321
# Epoch 203/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3614 - acc: 0.9457
# Epoch 204/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.3198 - acc: 0.9367
# Epoch 205/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3533 - acc: 0.9095
# Epoch 206/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3600 - acc: 0.9231
# Epoch 207/700
# 221/221 [==============================] - 0s 120us/step - loss: 0.3226 - acc: 0.9457
# Epoch 208/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.4121 - acc: 0.9095
# Epoch 209/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.4280 - acc: 0.9231
# Epoch 210/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.3501 - acc: 0.9593
# Epoch 211/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.3121 - acc: 0.9457
# Epoch 212/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3779 - acc: 0.9231
# Epoch 213/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.2773 - acc: 0.9593
# Epoch 214/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.3044 - acc: 0.9457
# Epoch 215/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.3884 - acc: 0.9095
# Epoch 216/700
# 221/221 [==============================] - 0s 124us/step - loss: 0.4171 - acc: 0.9140
# Epoch 217/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.4589 - acc: 0.8869
# Epoch 218/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.4118 - acc: 0.9140
# Epoch 219/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.3335 - acc: 0.9050
# Epoch 220/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.4565 - acc: 0.9005
# Epoch 221/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3222 - acc: 0.9367
# Epoch 222/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.4377 - acc: 0.9050
# Epoch 223/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.2895 - acc: 0.9457
# Epoch 224/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.3664 - acc: 0.9321
# Epoch 225/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.3976 - acc: 0.8959
# Epoch 226/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3817 - acc: 0.9412
# Epoch 227/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3582 - acc: 0.9276
# Epoch 228/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3364 - acc: 0.9231
# Epoch 229/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.4037 - acc: 0.9276
# Epoch 230/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.3996 - acc: 0.9457
# Epoch 231/700
# 221/221 [==============================] - 0s 122us/step - loss: 0.3781 - acc: 0.9231
# Epoch 232/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3770 - acc: 0.9457
# Epoch 233/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.3654 - acc: 0.9367
# Epoch 234/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2927 - acc: 0.9502
# Epoch 235/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.2396 - acc: 0.9593
# Epoch 236/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.2709 - acc: 0.9502
# Epoch 237/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.4175 - acc: 0.9095
# Epoch 238/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3390 - acc: 0.9367
# Epoch 239/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3730 - acc: 0.9457
# Epoch 240/700
# 221/221 [==============================] - 0s 130us/step - loss: 0.2128 - acc: 0.9548
# Epoch 241/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.3368 - acc: 0.9502
# Epoch 242/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.3110 - acc: 0.9502
# Epoch 243/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.3449 - acc: 0.9412
# Epoch 244/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3660 - acc: 0.9502
# Epoch 245/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.3307 - acc: 0.9548
# Epoch 246/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.2913 - acc: 0.9457
# Epoch 247/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2887 - acc: 0.9457
# Epoch 248/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.3860 - acc: 0.9321
# Epoch 249/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2999 - acc: 0.9638
# Epoch 250/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.2185 - acc: 0.9502
# Epoch 251/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.2864 - acc: 0.9548
# Epoch 252/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.2990 - acc: 0.9321
# Epoch 253/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.2405 - acc: 0.9593
# Epoch 254/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2978 - acc: 0.9593
# Epoch 255/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3331 - acc: 0.9276
# Epoch 256/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.3489 - acc: 0.9367
# Epoch 257/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.2486 - acc: 0.9502
# Epoch 258/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.2523 - acc: 0.9457
# Epoch 259/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3818 - acc: 0.9276
# Epoch 260/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.3292 - acc: 0.9502
# Epoch 261/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3070 - acc: 0.9412
# Epoch 262/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2641 - acc: 0.9502
# Epoch 263/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.3622 - acc: 0.9367
# Epoch 264/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.3868 - acc: 0.9140
# Epoch 265/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3033 - acc: 0.9683
# Epoch 266/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2658 - acc: 0.9548
# Epoch 267/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3370 - acc: 0.9412
# Epoch 268/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.4629 - acc: 0.9005
# Epoch 269/700
# 221/221 [==============================] - 0s 125us/step - loss: 0.3706 - acc: 0.9457
# Epoch 270/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.2177 - acc: 0.9729
# Epoch 271/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.3525 - acc: 0.9367
# Epoch 272/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3359 - acc: 0.9367
# Epoch 273/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.3001 - acc: 0.9412
# Epoch 274/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3368 - acc: 0.9593
# Epoch 275/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.2940 - acc: 0.9729
# Epoch 276/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.2908 - acc: 0.9457
# Epoch 277/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3255 - acc: 0.9638
# Epoch 278/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.3204 - acc: 0.9321
# Epoch 279/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.2923 - acc: 0.9412
# Epoch 280/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.2844 - acc: 0.9367
# Epoch 281/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.2465 - acc: 0.9819
# Epoch 282/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.3076 - acc: 0.9457
# Epoch 283/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.2552 - acc: 0.9638
# Epoch 284/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2815 - acc: 0.9412
# Epoch 285/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.2780 - acc: 0.9548
# Epoch 286/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.3310 - acc: 0.9321
# Epoch 287/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.3443 - acc: 0.9457
# Epoch 288/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.2248 - acc: 0.9683
# Epoch 289/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.3033 - acc: 0.9412
# Epoch 290/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2490 - acc: 0.9819
# Epoch 291/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3113 - acc: 0.9457
# Epoch 292/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2121 - acc: 0.9638
# Epoch 293/700
# 221/221 [==============================] - 0s 124us/step - loss: 0.2078 - acc: 0.9774
# Epoch 294/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.2758 - acc: 0.9638
# Epoch 295/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.2768 - acc: 0.9457
# Epoch 296/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1723 - acc: 0.9819
# Epoch 297/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.2686 - acc: 0.9457
# Epoch 298/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.3338 - acc: 0.9548
# Epoch 299/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.3487 - acc: 0.9321
# Epoch 300/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2941 - acc: 0.9593
# Epoch 301/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.2157 - acc: 0.9729
# Epoch 302/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3263 - acc: 0.9412
# Epoch 303/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.2900 - acc: 0.9593
# Epoch 304/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.2923 - acc: 0.9593
# Epoch 305/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.3481 - acc: 0.9186
# Epoch 306/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.2307 - acc: 0.9638
# Epoch 307/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.3127 - acc: 0.9367
# Epoch 308/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.3368 - acc: 0.9321
# Epoch 309/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1829 - acc: 0.9864
# Epoch 310/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.2965 - acc: 0.9367
# Epoch 311/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2306 - acc: 0.9774
# Epoch 312/700
# 221/221 [==============================] - 0s 127us/step - loss: 0.2683 - acc: 0.9502
# Epoch 313/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.3037 - acc: 0.9502
# Epoch 314/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1954 - acc: 0.9774
# Epoch 315/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2332 - acc: 0.9548
# Epoch 316/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2625 - acc: 0.9593
# Epoch 317/700
# 221/221 [==============================] - 0s 128us/step - loss: 0.2299 - acc: 0.9638
# Epoch 318/700
# 221/221 [==============================] - 0s 105us/step - loss: 0.2282 - acc: 0.9729
# Epoch 319/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.2791 - acc: 0.9548
# Epoch 320/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.2867 - acc: 0.9593
# Epoch 321/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.2375 - acc: 0.9548
# Epoch 322/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.2211 - acc: 0.9638
# Epoch 323/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.2825 - acc: 0.9502
# Epoch 324/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.2449 - acc: 0.9457
# Epoch 325/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.2689 - acc: 0.9638
# Epoch 326/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.2147 - acc: 0.9638
# Epoch 327/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.2381 - acc: 0.9683
# Epoch 328/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.2163 - acc: 0.9548
# Epoch 329/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.2624 - acc: 0.9548
# Epoch 330/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2706 - acc: 0.9638
# Epoch 331/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.2419 - acc: 0.9457
# Epoch 332/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2557 - acc: 0.9638
# Epoch 333/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1930 - acc: 0.9774
# Epoch 334/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1888 - acc: 0.9729
# Epoch 335/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.3168 - acc: 0.9457
# Epoch 336/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1962 - acc: 0.9729
# Epoch 337/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1991 - acc: 0.9638
# Epoch 338/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.2613 - acc: 0.9729
# Epoch 339/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.2611 - acc: 0.9502
# Epoch 340/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1789 - acc: 0.9729
# Epoch 341/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1711 - acc: 0.9683
# Epoch 342/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.2331 - acc: 0.9593
# Epoch 343/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1947 - acc: 0.9683
# Epoch 344/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.2579 - acc: 0.9548
# Epoch 345/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1949 - acc: 0.9638
# Epoch 346/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.1888 - acc: 0.9638
# Epoch 347/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1996 - acc: 0.9729
# Epoch 348/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.1742 - acc: 0.9683
# Epoch 349/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.2241 - acc: 0.9638
# Epoch 350/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1959 - acc: 0.9774
# Epoch 351/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.2037 - acc: 0.9548
# Epoch 352/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1898 - acc: 0.9683
# Epoch 353/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.2551 - acc: 0.9638
# Epoch 354/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.2095 - acc: 0.9502
# Epoch 355/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2171 - acc: 0.9593
# Epoch 356/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2184 - acc: 0.9638
# Epoch 357/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1856 - acc: 0.9729
# Epoch 358/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1513 - acc: 0.9819
# Epoch 359/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.2188 - acc: 0.9502
# Epoch 360/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1980 - acc: 0.9457
# Epoch 361/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2073 - acc: 0.9729
# Epoch 362/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2405 - acc: 0.9502
# Epoch 363/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.1753 - acc: 0.9774
# Epoch 364/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1609 - acc: 0.9955
# Epoch 365/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.1168 - acc: 0.9819
# Epoch 366/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1963 - acc: 0.9683
# Epoch 367/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1686 - acc: 0.9774
# Epoch 368/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1368 - acc: 0.9774
# Epoch 369/700
# 221/221 [==============================] - 0s 130us/step - loss: 0.2011 - acc: 0.9683
# Epoch 370/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1941 - acc: 0.9774
# Epoch 371/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.2514 - acc: 0.9457
# Epoch 372/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1651 - acc: 0.9729
# Epoch 373/700
# 221/221 [==============================] - 0s 122us/step - loss: 0.2124 - acc: 0.9593
# Epoch 374/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2038 - acc: 0.9683
# Epoch 375/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.1625 - acc: 0.9729
# Epoch 376/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1769 - acc: 0.9638
# Epoch 377/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.2285 - acc: 0.9457
# Epoch 378/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1658 - acc: 0.9774
# Epoch 379/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.1834 - acc: 0.9729
# Epoch 380/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1439 - acc: 0.9819
# Epoch 381/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1634 - acc: 0.9638
# Epoch 382/700
# 221/221 [==============================] - 0s 123us/step - loss: 0.2303 - acc: 0.9457
# Epoch 383/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.2016 - acc: 0.9683
# Epoch 384/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1822 - acc: 0.9819
# Epoch 385/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1795 - acc: 0.9638
# Epoch 386/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1791 - acc: 0.9774
# Epoch 387/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1384 - acc: 0.9774
# Epoch 388/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.1310 - acc: 0.9864
# Epoch 389/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.1892 - acc: 0.9593
# Epoch 390/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2276 - acc: 0.9457
# Epoch 391/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0974 - acc: 0.9864
# Epoch 392/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1583 - acc: 0.9683
# Epoch 393/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1653 - acc: 0.9683
# Epoch 394/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0945 - acc: 0.9910
# Epoch 395/700
# 221/221 [==============================] - 0s 123us/step - loss: 0.2715 - acc: 0.9276
# Epoch 396/700
# 221/221 [==============================] - 0s 123us/step - loss: 0.1195 - acc: 0.9864
# Epoch 397/700
# 221/221 [==============================] - 0s 120us/step - loss: 0.1883 - acc: 0.9638
# Epoch 398/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.1764 - acc: 0.9593
# Epoch 399/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1773 - acc: 0.9548
# Epoch 400/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.2058 - acc: 0.9638
# Epoch 401/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1408 - acc: 0.9774
# Epoch 402/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.1847 - acc: 0.9683
# Epoch 403/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1590 - acc: 0.9774
# Epoch 404/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.1208 - acc: 0.9774
# Epoch 405/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1928 - acc: 0.9502
# Epoch 406/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1267 - acc: 0.9819
# Epoch 407/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.2011 - acc: 0.9457
# Epoch 408/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1380 - acc: 0.9729
# Epoch 409/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1478 - acc: 0.9774
# Epoch 410/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1738 - acc: 0.9638
# Epoch 411/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1130 - acc: 0.9864
# Epoch 412/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1527 - acc: 0.9729
# Epoch 413/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1767 - acc: 0.9729
# Epoch 414/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.2016 - acc: 0.9548
# Epoch 415/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1848 - acc: 0.9593
# Epoch 416/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1938 - acc: 0.9548
# Epoch 417/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.1423 - acc: 0.9729
# Epoch 418/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1957 - acc: 0.9593
# Epoch 419/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1624 - acc: 0.9638
# Epoch 420/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1184 - acc: 0.9819
# Epoch 421/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.1153 - acc: 0.9774
# Epoch 422/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1005 - acc: 0.9864
# Epoch 423/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1531 - acc: 0.9774
# Epoch 424/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1244 - acc: 0.9683
# Epoch 425/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1187 - acc: 0.9774
# Epoch 426/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1765 - acc: 0.9593
# Epoch 427/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1390 - acc: 0.9819
# Epoch 428/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1353 - acc: 0.9774
# Epoch 429/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1341 - acc: 0.9548
# Epoch 430/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.2715 - acc: 0.9367
# Epoch 431/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.1552 - acc: 0.9593
# Epoch 432/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1656 - acc: 0.9593
# Epoch 433/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1412 - acc: 0.9774
# Epoch 434/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.1117 - acc: 0.9910
# Epoch 435/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1645 - acc: 0.9683
# Epoch 436/700
# 221/221 [==============================] - 0s 127us/step - loss: 0.1837 - acc: 0.9548
# Epoch 437/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1721 - acc: 0.9548
# Epoch 438/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1424 - acc: 0.9638
# Epoch 439/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0511 - acc: 1.0000
# Epoch 440/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.1419 - acc: 0.9774
# Epoch 441/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1792 - acc: 0.9548
# Epoch 442/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1134 - acc: 0.9819
# Epoch 443/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0792 - acc: 0.9955
# Epoch 444/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1394 - acc: 0.9593
# Epoch 445/700
# 221/221 [==============================] - 0s 137us/step - loss: 0.1817 - acc: 0.9593
# Epoch 446/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0886 - acc: 0.9955
# Epoch 447/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1703 - acc: 0.9548
# Epoch 448/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1153 - acc: 0.9910
# Epoch 449/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.1073 - acc: 0.9729
# Epoch 450/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.1510 - acc: 0.9729
# Epoch 451/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.1648 - acc: 0.9593
# Epoch 452/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.1656 - acc: 0.9638
# Epoch 453/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.1274 - acc: 0.9683
# Epoch 454/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.1184 - acc: 0.9774
# Epoch 455/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1672 - acc: 0.9593
# Epoch 456/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1204 - acc: 0.9593
# Epoch 457/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1135 - acc: 0.9729
# Epoch 458/700
# 221/221 [==============================] - 0s 120us/step - loss: 0.0926 - acc: 0.9864
# Epoch 459/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1702 - acc: 0.9548
# Epoch 460/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.1784 - acc: 0.9593
# Epoch 461/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1564 - acc: 0.9593
# Epoch 462/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1179 - acc: 0.9683
# Epoch 463/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.1188 - acc: 0.9819
# Epoch 464/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1457 - acc: 0.9683
# Epoch 465/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1165 - acc: 0.9774
# Epoch 466/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1388 - acc: 0.9683
# Epoch 467/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.0771 - acc: 0.9910
# Epoch 468/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1276 - acc: 0.9729
# Epoch 469/700
# ...
# Epoch 542/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.1206 - acc: 0.9683
# Epoch 543/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0717 - acc: 0.9864
# Epoch 544/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.0873 - acc: 0.9819
# Epoch 545/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1044 - acc: 0.9683
# Epoch 546/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.0930 - acc: 0.9729
# Epoch 547/700
# 221/221 [==============================] - 0s 132us/step - loss: 0.1313 - acc: 0.9683
# Epoch 548/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.0542 - acc: 0.9864
# Epoch 549/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1170 - acc: 0.9819
# Epoch 550/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.0930 - acc: 0.9774
# Epoch 551/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.0842 - acc: 0.9819
# Epoch 552/700
# 221/221 [==============================] - 0s 140us/step - loss: 0.0937 - acc: 0.9683
# Epoch 553/700
# 221/221 [==============================] - 0s 130us/step - loss: 0.1292 - acc: 0.9638
# Epoch 554/700
# 221/221 [==============================] - 0s 141us/step - loss: 0.1094 - acc: 0.9683
# Epoch 555/700
# 221/221 [==============================] - 0s 136us/step - loss: 0.0787 - acc: 0.9864
# Epoch 556/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1057 - acc: 0.9819
# Epoch 557/700
# 221/221 [==============================] - 0s 123us/step - loss: 0.1198 - acc: 0.9683
# Epoch 558/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0796 - acc: 0.9864
# Epoch 559/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.1461 - acc: 0.9593
# Epoch 560/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.0724 - acc: 0.9819
# Epoch 561/700
# 221/221 [==============================] - 0s 120us/step - loss: 0.0493 - acc: 0.9910
# Epoch 562/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0598 - acc: 0.9955
# Epoch 563/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0889 - acc: 0.9819
# Epoch 564/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.0522 - acc: 0.9910
# Epoch 565/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0995 - acc: 0.9774
# Epoch 566/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1266 - acc: 0.9729
# Epoch 567/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.0945 - acc: 0.9729
# Epoch 568/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.0933 - acc: 0.9819
# Epoch 569/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0921 - acc: 0.9910
# Epoch 570/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.0724 - acc: 0.9819
# Epoch 571/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0915 - acc: 0.9819
# Epoch 572/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.0623 - acc: 0.9910
# Epoch 573/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1176 - acc: 0.9683
# Epoch 574/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.1338 - acc: 0.9638
# Epoch 575/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1187 - acc: 0.9729
# Epoch 576/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.1000 - acc: 0.9729
# Epoch 577/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1224 - acc: 0.9729
# Epoch 578/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.0618 - acc: 0.9955
# Epoch 579/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1356 - acc: 0.9683
# Epoch 580/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0651 - acc: 0.9955
# Epoch 581/700
# 221/221 [==============================] - 0s 120us/step - loss: 0.0881 - acc: 0.9864
# Epoch 582/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0678 - acc: 0.9864
# Epoch 583/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0651 - acc: 0.9819
# Epoch 584/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.1188 - acc: 0.9774
# Epoch 585/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0948 - acc: 0.9729
# Epoch 586/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1098 - acc: 0.9819
# Epoch 587/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0918 - acc: 0.9819
# Epoch 588/700
# 221/221 [==============================] - 0s 122us/step - loss: 0.0968 - acc: 0.9864
# Epoch 589/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.0617 - acc: 0.9955
# Epoch 590/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.0664 - acc: 0.9864
# Epoch 591/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0860 - acc: 0.9864
# Epoch 592/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0797 - acc: 0.9774
# Epoch 593/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.0875 - acc: 0.9729
# Epoch 594/700
# 221/221 [==============================] - 0s 105us/step - loss: 0.0574 - acc: 0.9955
# Epoch 595/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.0720 - acc: 0.9910
# Epoch 596/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.0784 - acc: 0.9819
# Epoch 597/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0325 - acc: 1.0000
# Epoch 598/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.0868 - acc: 0.9729
# Epoch 599/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.0847 - acc: 0.9819
# Epoch 600/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.1163 - acc: 0.9729
# Epoch 601/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1311 - acc: 0.9729
# Epoch 602/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.0840 - acc: 0.9864
# Epoch 603/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.1264 - acc: 0.9638
# Epoch 604/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0863 - acc: 0.9774
# Epoch 605/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.0723 - acc: 0.9819
# Epoch 606/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.0939 - acc: 0.9910
# Epoch 607/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.0978 - acc: 0.9774
# Epoch 608/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0850 - acc: 0.9729
# Epoch 609/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0820 - acc: 0.9864
# Epoch 610/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.1457 - acc: 0.9683
# Epoch 611/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0410 - acc: 0.9955
# Epoch 612/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1042 - acc: 0.9774
# Epoch 613/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0923 - acc: 0.9729
# Epoch 614/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.0747 - acc: 0.9774
# Epoch 615/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.0720 - acc: 0.9774
# Epoch 616/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.0949 - acc: 0.9819
# Epoch 617/700
# 221/221 [==============================] - 0s 127us/step - loss: 0.1534 - acc: 0.9683
# Epoch 618/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.0796 - acc: 0.9774
# Epoch 619/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.0957 - acc: 0.9774
# Epoch 620/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.1035 - acc: 0.9683
# Epoch 621/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.0878 - acc: 0.9819
# Epoch 622/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1280 - acc: 0.9774
# Epoch 623/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0522 - acc: 0.9910
# Epoch 624/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1279 - acc: 0.9683
# Epoch 625/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0859 - acc: 0.9774
# Epoch 626/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0887 - acc: 0.9819
# Epoch 627/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0485 - acc: 0.9955
# Epoch 628/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.1293 - acc: 0.9638
# Epoch 629/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.0834 - acc: 0.9910
# Epoch 630/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.0831 - acc: 0.9729
# Epoch 631/700
# 221/221 [==============================] - 0s 106us/step - loss: 0.0496 - acc: 0.9910
# Epoch 632/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0891 - acc: 0.9774
# Epoch 633/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.0459 - acc: 0.9910
# Epoch 634/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.0873 - acc: 0.9819
# Epoch 635/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0377 - acc: 0.9955
# Epoch 636/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0687 - acc: 0.9864
# Epoch 637/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0781 - acc: 0.9910
# Epoch 638/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0628 - acc: 0.9864
# Epoch 639/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.1009 - acc: 0.9729
# Epoch 640/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.0534 - acc: 1.0000
# Epoch 641/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0894 - acc: 0.9819
# Epoch 642/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0779 - acc: 0.9864
# Epoch 643/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.1303 - acc: 0.9729
# Epoch 644/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.0650 - acc: 0.9729
# Epoch 645/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.0523 - acc: 0.9910
# Epoch 646/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.0642 - acc: 0.9864
# Epoch 647/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.0434 - acc: 0.9864
# Epoch 648/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0643 - acc: 0.9819
# Epoch 649/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.0690 - acc: 0.9819
# Epoch 650/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0267 - acc: 1.0000
# Epoch 651/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.0571 - acc: 0.9910
# Epoch 652/700
# 221/221 [==============================] - 0s 105us/step - loss: 0.1106 - acc: 0.9729
# Epoch 653/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.0943 - acc: 0.9864
# Epoch 654/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0854 - acc: 0.9819
# Epoch 655/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.0807 - acc: 0.9819
# Epoch 656/700
# 221/221 [==============================] - 0s 107us/step - loss: 0.0792 - acc: 0.9819
# Epoch 657/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1125 - acc: 0.9729
# Epoch 658/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.0505 - acc: 0.9864
# Epoch 659/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0715 - acc: 0.9819
# Epoch 660/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.0555 - acc: 1.0000
# Epoch 661/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.0956 - acc: 0.9774
# Epoch 662/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0295 - acc: 1.0000
# Epoch 663/700
# 221/221 [==============================] - 0s 118us/step - loss: 0.0475 - acc: 0.9955
# Epoch 664/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.0719 - acc: 0.9910
# Epoch 665/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.0732 - acc: 0.9955
# Epoch 666/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0477 - acc: 0.9910
# Epoch 667/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0878 - acc: 0.9819
# Epoch 668/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0870 - acc: 0.9864
# Epoch 669/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.1053 - acc: 0.9729
# Epoch 670/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0370 - acc: 0.9910
# Epoch 671/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0626 - acc: 0.9910
# Epoch 672/700
# 221/221 [==============================] - 0s 109us/step - loss: 0.1495 - acc: 0.9502
# Epoch 673/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0904 - acc: 0.9729
# Epoch 674/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1110 - acc: 0.9774
# Epoch 675/700
# 221/221 [==============================] - 0s 115us/step - loss: 0.1026 - acc: 0.9683
# Epoch 676/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.1528 - acc: 0.9593
# Epoch 677/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0509 - acc: 0.9955
# Epoch 678/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.0747 - acc: 0.9774
# Epoch 679/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0416 - acc: 0.9955
# Epoch 680/700
# 221/221 [==============================] - 0s 128us/step - loss: 0.0569 - acc: 0.9819
# Epoch 681/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0406 - acc: 0.9955
# Epoch 682/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.0796 - acc: 0.9774
# Epoch 683/700
# 221/221 [==============================] - 0s 116us/step - loss: 0.0467 - acc: 0.9864
# Epoch 684/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.1369 - acc: 0.9683
# Epoch 685/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0918 - acc: 0.9819
# Epoch 686/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0464 - acc: 0.9910
# Epoch 687/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0746 - acc: 0.9864
# Epoch 688/700
# 221/221 [==============================] - 0s 104us/step - loss: 0.0708 - acc: 0.9864
# Epoch 689/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0661 - acc: 0.9864
# Epoch 690/700
# 221/221 [==============================] - 0s 108us/step - loss: 0.0584 - acc: 0.9864
# Epoch 691/700
# 221/221 [==============================] - 0s 114us/step - loss: 0.0575 - acc: 0.9955
# Epoch 692/700
# 221/221 [==============================] - 0s 112us/step - loss: 0.0840 - acc: 0.9864
# Epoch 693/700
# 221/221 [==============================] - 0s 110us/step - loss: 0.0390 - acc: 0.9910
# Epoch 694/700
# 221/221 [==============================] - 0s 111us/step - loss: 0.1185 - acc: 0.9774
# Epoch 695/700
# 221/221 [==============================] - 0s 121us/step - loss: 0.0840 - acc: 0.9819
# Epoch 696/700
# 221/221 [==============================] - 0s 126us/step - loss: 0.0808 - acc: 0.9819
# Epoch 697/700
# 221/221 [==============================] - 0s 128us/step - loss: 0.0743 - acc: 0.9864
# Epoch 698/700
# 221/221 [==============================] - 0s 113us/step - loss: 0.0564 - acc: 0.9864
# Epoch 699/700
# 221/221 [==============================] - 0s 119us/step - loss: 0.0951 - acc: 0.9819
# Epoch 700/700
# 221/221 [==============================] - 0s 117us/step - loss: 0.1004 - acc: 0.9729
# Processed actions: 221it [00:00, 1315.57it/s, # examples=221]

# %% [markdown]
# # Talk to your Bot

# %%
#Starting the Bot
from rasa_core.utils import read_endpoint_config
from rasa_core.agent import Agent
agent = Agent.load('models/dialogue', interpreter=model_directory,action_endpoint="http://localhost:5055/webhook")
# Out:
# INFO:tensorflow:Restoring parameters from /Users/saching12/Desktop/python codes/student_assistant_chatbot/./models/nlu/default/current/intent_classifier_tensorflow_embedding.ckpt

# %%
print("Your bot is ready to talk! Type your messages here or send 'stop'")
while True:
    a = input()
    if a == 'stop':
        break
    responses = agent.handle_text(a)
    for response in responses:
        print(response["text"])
# Out:
# Your bot is ready to talk! Type your messages here or send 'stop'
# is there any event happening tomorrow?
# stop

# %%
exit
