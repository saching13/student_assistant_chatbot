# %% [markdown]
# # Building a Conversational Chatbot for Slack using Rasa and Python -Part 1

# %% [markdown]
# ## Starting Jupyter Notebook with necessary imports

# %%
# %matplotlib inline

import logging, io, json, warnings
logging.basicConfig(level="INFO")
warnings.filterwarnings('ignore')

# %% [markdown]
# # Installations
# * Rasa NLU
# * Rasa Core
# * SpaCy Language Model

# %%
import sys
python = sys.executable

# In your environment run:
# !{python} -m pip install -U rasa_core==0.9.6 rasa_nlu[spacy];
# Out:
# Collecting rasa_core==0.9.6
#   Using cached https://files.pythonhosted.org/packages/72/de/82e762685a991351a9f89d934b1b25fe04d10462cf4017f93227cb4d9058/rasa_core-0.9.6-py2.py3-none-any.whl
# Collecting rasa_nlu[spacy]
#   Using cached https://files.pythonhosted.org/packages/d6/53/31b6b14e124fa916c10e8e58d650cff57ace0027a9e69a0788b1afcc26f4/rasa_nlu-0.14.6-py2.py3-none-any.whl
# Collecting python-telegram-bot~=10.0 (from rasa_core==0.9.6)
#   Using cached https://files.pythonhosted.org/packages/f1/51/d1bd383522c12b313eddd7b97b8e7d6cd2a8e3b44b8ff3c88e4a7b045cc8/python_telegram_bot-10.1.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: coloredlogs~=10.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (10.0)
# Requirement already satisfied, skipping upgrade: ConfigArgParse~=0.13.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (0.13.0)
# Requirement already satisfied, skipping upgrade: graphviz~=0.8.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (0.8.4)
# Requirement already satisfied, skipping upgrade: requests~=2.15 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (2.21.0)
# Requirement already satisfied, skipping upgrade: mattermostwrapper~=2.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (2.1)
# Requirement already satisfied, skipping upgrade: fbmessenger~=5.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (5.4.0)
# Requirement already satisfied, skipping upgrade: flask-cors~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (3.0.7)
# Requirement already satisfied, skipping upgrade: ruamel.yaml~=0.15.0 in /usr/local/lib/python3.6/site-packages (from rasa_core==0.9.6) (0.15.89)
# Collecting tensorflow<1.9,>=1.7 (from rasa_core==0.9.6)
#   Using cached https://files.pythonhosted.org/packages/03/ad/d732a5d9d50bfcd8aeb6e4a266065a8868829388e4e2b529ff689f1fc923/tensorflow-1.8.0-cp36-cp36m-macosx_10_11_x86_64.whl
# ^C
# Operation cancelled by user

# %%
# !{python} -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: en_core_web_md==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz#egg=en_core_web_md==2.0.0 in /usr/local/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /usr/local/lib/python3.6/site-packages/en_core_web_md -->
#     /usr/local/lib/python3.6/site-packages/spacy/data/en_core_web_md
#
#     You can now load the model via spacy.load('en_core_web_md')

# %% [markdown]
# ## Downloading the English Language Model

# %%
# !{python} -m spacy link en_core_web_md en --force;
# Out:
#     Linking successful
#     /usr/local/lib/python3.6/site-packages/en_core_web_md -->
#     /usr/local/lib/python3.6/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')

# %%
# !pip install rasa_core
# Out:
# Requirement already satisfied: rasa_core in /usr/local/lib/python3.6/site-packages (0.13.3)
# Requirement already satisfied: keras-applications==1.0.6 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.6)
# Requirement already satisfied: flask-cors~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.0.7)
# Requirement already satisfied: slackclient~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.3.1)
# Requirement already satisfied: coloredlogs~=10.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (10.0)
# Requirement already satisfied: requests~=2.20 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.21.0)
# Requirement already satisfied: fbmessenger~=5.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (5.4.0)
# Requirement already satisfied: rasa-nlu~=0.14.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.14.4)
# Requirement already satisfied: tqdm~=4.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (4.31.1)
# Requirement already satisfied: packaging~=18.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (18.0)
# Requirement already satisfied: rocketchat-API~=0.6.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.6.27)
# Requirement already satisfied: twilio~=6.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (6.25.1)
# Requirement already satisfied: webexteamssdk~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.1.1)
# Requirement already satisfied: ruamel.yaml~=0.15.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.15.89)
# Requirement already satisfied: gevent~=1.4 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.4.0)
# Requirement already satisfied: python-telegram-bot~=11.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (11.1.0)
# Requirement already satisfied: mattermostwrapper~=2.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.1)
# Requirement already satisfied: rasa-core-sdk~=0.12.1 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.12.2)
# Requirement already satisfied: pymongo~=3.7 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.7.2)
# Requirement already satisfied: jsonschema~=2.6 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.6.0)
# Requirement already satisfied: questionary>=1.0.1 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: tensorflow~=1.12.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.12.0)
# Requirement already satisfied: scipy~=1.2 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.2.1)
# Requirement already satisfied: apscheduler~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.5.3)
# Requirement already satisfied: pydot~=1.4 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.4.1)
# Requirement already satisfied: redis~=2.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.10.6)
# Requirement already satisfied: typing~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.6.6)
# Requirement already satisfied: pykwalify~=1.7.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.7.0)
# Requirement already satisfied: python-socketio~=3.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.1.2)
# Requirement already satisfied: flask-jwt-simple~=0.0.3 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.0.3)
# Requirement already satisfied: scikit-learn~=0.20.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.20.3)
# Requirement already satisfied: pytz~=2018.9 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2018.9)
# Requirement already satisfied: jsonpickle~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.1)
# Requirement already satisfied: python-dateutil~=2.7 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.7.5)
# Requirement already satisfied: flask~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: colorclass~=2.2 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.2.0)
# Requirement already satisfied: networkx~=2.2 in /usr/local/lib/python3.6/site-packages (from rasa_core) (2.2)
# Requirement already satisfied: terminaltables~=3.1 in /usr/local/lib/python3.6/site-packages (from rasa_core) (3.1.0)
# Requirement already satisfied: fakeredis~=0.10.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.10.3)
# Requirement already satisfied: numpy~=1.16 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.16.2)
# Requirement already satisfied: keras-preprocessing==1.0.5 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.5)
# Requirement already satisfied: colorhash~=1.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: pika~=0.12.0 in /usr/local/lib/python3.6/site-packages (from rasa_core) (0.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/site-packages (from keras-applications==1.0.6->rasa_core) (2.8.0)
# Requirement already satisfied: Six in /usr/local/lib/python3.6/site-packages (from flask-cors~=3.0->rasa_core) (1.11.0)
# Requirement already satisfied: websocket-client<0.55.0,>=0.35 in /usr/local/lib/python3.6/site-packages (from slackclient~=1.0->rasa_core) (0.54.0)
# Requirement already satisfied: humanfriendly>=4.7 in /usr/local/lib/python3.6/site-packages (from coloredlogs~=10.0->rasa_core) (4.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests~=2.20->rasa_core) (1.24.1)
# Requirement already satisfied: matplotlib~=2.0 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (2.2.4)
# Requirement already satisfied: cloudpickle~=0.6.1 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (0.6.1)
# Requirement already satisfied: boto3~=1.5 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (1.9.113)
# Requirement already satisfied: simplejson~=3.13 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (3.16.0)
# Requirement already satisfied: klein~=17.10 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (17.10.0)
# Requirement already satisfied: future~=0.17.1 in /usr/local/lib/python3.6/site-packages (from rasa-nlu~=0.14.0->rasa_core) (0.17.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/site-packages (from packaging~=18.0->rasa_core) (2.3.0)
# Requirement already satisfied: PyJWT>=1.4.2 in /usr/local/lib/python3.6/site-packages (from twilio~=6.0->rasa_core) (1.7.1)
# Requirement already satisfied: pysocks; python_version >= "3.0" in /usr/local/lib/python3.6/site-packages (from twilio~=6.0->rasa_core) (1.6.8)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.6/site-packages (from webexteamssdk~=1.0->rasa_core) (0.9.1)
# Requirement already satisfied: greenlet>=0.4.14; platform_python_implementation == "CPython" in /usr/local/lib/python3.6/site-packages (from gevent~=1.4->rasa_core) (0.4.15)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.6/site-packages (from python-telegram-bot~=11.0->rasa_core) (2.6.1)
# Requirement already satisfied: ConfigArgParse~=0.13.0 in /usr/local/lib/python3.6/site-packages (from rasa-core-sdk~=0.12.1->rasa_core) (0.13.0)
# Requirement already satisfied: prompt-toolkit~=2.0 in /usr/local/lib/python3.6/site-packages (from questionary>=1.0.1->rasa_core) (2.0.7)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (3.6.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (1.16.1)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (0.6.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (0.7.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (0.2.0)
# Requirement already satisfied: tensorboard<1.13.0,>=1.12.0 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (1.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/site-packages (from tensorflow~=1.12.0->rasa_core) (0.31.1)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.6/site-packages (from apscheduler~=3.0->rasa_core) (1.5.1)
# Requirement already satisfied: setuptools>=0.7 in /usr/local/lib/python3.6/site-packages (from apscheduler~=3.0->rasa_core) (39.2.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/site-packages (from pykwalify~=1.7.0->rasa_core) (3.13)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.6/site-packages (from pykwalify~=1.7.0->rasa_core) (0.6.2)
# Requirement already satisfied: python-engineio>=3.2.0 in /usr/local/lib/python3.6/site-packages (from python-socketio~=3.0->rasa_core) (3.4.3)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (2.10)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (7.0)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/site-packages (from flask~=1.0->rasa_core) (0.14.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/site-packages (from networkx~=2.2->rasa_core) (4.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/site-packages (from matplotlib~=2.0->rasa-nlu~=0.14.0->rasa_core) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/site-packages (from matplotlib~=2.0->rasa-nlu~=0.14.0->rasa_core) (1.0.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.2.0)
# Requirement already satisfied: botocore<1.13.0,>=1.12.113 in /usr/local/lib/python3.6/site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (1.12.113)
# Requirement already satisfied: Twisted>=15.5 in /usr/local/lib/python3.6/site-packages (from klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (18.9.0)
# Requirement already satisfied: incremental in /usr/local/lib/python3.6/site-packages (from klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (17.5.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (1.12.2)
# Requirement already satisfied: asn1crypto>=0.21.0 in /usr/local/lib/python3.6/site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (0.24.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/site-packages (from prompt-toolkit~=2.0->questionary>=1.0.1->rasa_core) (0.1.7)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/site-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow~=1.12.0->rasa_core) (3.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/site-packages (from Jinja2>=2.10->flask~=1.0->rasa_core) (1.1.0)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.113->boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.14)
# Requirement already satisfied: Automat>=0.3.0 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (0.7.0)
# Requirement already satisfied: PyHamcrest>=1.9.0 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (1.9.0)
# Requirement already satisfied: zope.interface>=4.4.2 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (4.6.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (19.1.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (18.0.0)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.6/site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (15.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography->python-telegram-bot~=11.0->rasa_core) (2.19)

# %% [markdown]
# # Importing the Installations

# %%
import rasa_nlu
import rasa_core
import spacy

# %% [markdown]
# # 1. Teaching the bot to understand user inputs using Rasa NLU

# %% [markdown]
# ## Preparing the NLU Training Data

# %% [markdown]
# nlu_md = """
# ## intent:greet
# - hey
# - hello there
# - hi
# - hello there
# - good morning
# - good evening
# - moin
# - hey there
# - let's go
# - hey dude
# - goodmorning
# - goodevening
# - good afternoon
#
# ## intent:goodbye
# - cu
# - good by
# - cee you later
# - good night
# - good afternoon
# - bye
# - goodbye
# - have a nice day
# - see you around
# - bye bye
# - see you later
#
# ## intent:mood_affirm
# - yes
# - indeed
# - of course
# - that sounds good
# - correct
#
# ## intent:mood_deny
# - no
# - never
# - I don't think so
# - don't like that
# - no way
# - not really
#
#
#
#
# ## intent:student_work_authorization
# - What does the student’s work authorization look like?
# - how is student work authorization?
# - how does student work authorization look like?
# - Student work authorization look?
# - what's Student work authorization
#
# ## intent:student_work
# - When can a student work?
# - When can I work?
#
#
# ## intent:student_work_timings
# - How many hours per week can a student work?
# - How many hours can I work?
# - number of hours I can work?
# - no. of hours I can work?
#
# ## intent:taxes
# - Are F-1 students subject to taxes?
# - am I subjected to tax ?
# - how much tax shoud I pay ?
# - should I pay tax ?
#
# ## intent:E_verify
# - What is E-Verify?
# - how to do e-verify?
# - What is E Verify?
# - how to do e verify?
# - What is EVerify?
# - how to do everify
#
# ##intent: Visa_interview
# -What all do I need for Visa Interview?
# -what all documents do I need for Visa Interview?
# -Documents needed for Visa Interview?
# -What all things do I need for Visa Interview?
# -What all papaers do I need for Visa Interview?
#
# ##intent: travel_date
# -When can I travel to the usa?
# -How many days prior to my admission can I travel to the USA?
#
# ## intent:customs_immigration
# -What all do I need for customs and immigration?
# -what all documents do I need for customs and immigration?
# -Documents needed for customs and immigration?
# -What all things do I need for customs and immigration?
# -What all papaers do I need for customs and immigration?
#
# ##intent:questions_during_visa
# -What are the common questions asked during Visa interview?
# -What should I prepare for Visa interview?
# -What kind of questions are asked during a visa interview?
# -Common questions durin Visa interview?
# -Questions asked in a Visa interview?
#
# ##intent:health_insurance
# -How do I pyrchase University heath insurance?
# -What steps are involved in purchasing student health insurance?
# -Steps to purchase health insurance?
# -international Heath Insurance puchase?
#
# ##intent:immunization
# -What are the steps involved in immunization?
# -What all immunization do I need before getting to the USA?
# -Kind of immunization required before reaching?
# -What is the proof of immunization that needs to be submitted?
#
# ##intent:housing
# -Where can I find the housing details of SJSU?
# -Accomodation in SJSU?
# -Accomodation for international students at SJSU?
# -Housing for students near SJSU?
# -Housing on campus?
#
# ##intent:course_registration
# -How many courses do I need to register for?
# -How many credits are mandatory?
# -Number of credits at SJSU?
# -SJSU credits for F1 students?
#
# ##intent:tution
# -Where can I find details about my tution fees?
# -Information about tution fees?
# -When do I have to pay for tution fees?
# -When can I register for the courses?
# -Where do I pay my tution?
#
# ##intent:tower_ID
# -Where can I get my ID?
# -Do I need an ID?
# -Procedure to get an ID?
# -Documents required to get an ID?
# -How do I get my student ID?
# -Steps involved in getting student ID card?
#
# ## intent: inform
# - A [dog](group:shibes)
# - [dog](group:shibes)
# - [bird](group:birds)
# - a [cat](group:cats)
# - [cat](group:cats)
# - a [bird](group:birds)
# - of a [dog](group:shibes)
# - of a [cat](group:cats)
# - a [bird](group:birds), please
# - a [dog](group:shibes), please
# """
#
# %store nlu_md > nlu.md

# %%
# %ls
# Out:
# chatbot_config.py                nlu_model.py
# config.yml                       policy_config.yml
# domain.yml                       slack_connector.py
# errors.json                      stories.md
# models/                          stories_backup.md
# nlu.md                           story_graph.png
# nlu_config.yml                   student_assistant_chatbot.ipynb

# %% [markdown]
# ## Defining the NLU Model Configuration

# %%
config = """
language: "en"

pipeline:
- name: "nlp_spacy"
- name: "tokenizer_spacy"
- name: "intent_entity_featurizer_regex"
- name: "intent_featurizer_spacy"
- name: "ner_crf"
- name: "ner_synonyms"
- name: "intent_classifier_sklearn"
"""

# %store config > nlu_config.yml
# Out:
# Writing 'config' (str) to file 'nlu_config.yml'.

# %%
config = """
language: "en"

pipeline:
- name: "tokenizer_whitespace"
- name: "ner_crf"
- name: "ner_synonyms"
- name: "intent_featurizer_count_vectors"
- name: "intent_classifier_tensorflow_embedding"
- name: "ner_duckling_http"
  url: "http://127.0.0.1:8000"
  dimensions: ["time"] 
"""

# %store config > nlu_config.yml
# Out:
# Writing 'config' (str) to file 'nlu_config.yml'.

# %% [markdown]
# ## Training the NLU Model.

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# loading the nlu training samples
training_data = load_data("nlu.md")

# trainer to educate our pipeline
trainer = Trainer(config.load("nlu_config.yml"))

# train the model!
interpreter = trainer.train(training_data)

# store it for future use
model_directory = trainer.persist("./models/nlu", fixed_model_name="current")
# Out:
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 104 (20 distinct intents)
# 	- Found intents: 'student_work_timings', 'tution', 'questions_during_visa', 'E_verify', 'health_insurance', 'housing', 'student_work', 'greet', 'tower_ID', 'goodbye', 'travel_date', 'inform', 'student_work_authorization', 'course_registration', 'customs_immigration', 'taxes', 'immunization', 'mood_affirm', 'Visa_interview', 'mood_deny'
# 	- entity examples: 3 (2 distinct entities)
# 	- found entities: 'time', 'events'
#
# INFO:rasa_nlu.model:Starting to train component tokenizer_whitespace
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component ner_crf
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component ner_synonyms
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component intent_featurizer_count_vectors
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component intent_classifier_tensorflow_embedding
# INFO:rasa_nlu.classifiers.embedding_intent_classifier:Accuracy is updated every 10 epochs
# Epochs: 100%|██████████| 300/300 [00:02<00:00, 101.07it/s, loss=0.145, acc=0.990]
# INFO:rasa_nlu.classifiers.embedding_intent_classifier:Finished training embedding classifier, loss=0.145, train accuracy=0.990
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component ner_duckling_http
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Successfully saved model into '/Users/saching12/Desktop/python codes/student_assistant_chatbot/models/nlu/default/current'

# %% [markdown]
# ## Evaluating the NLU model on a random text

# %%
# A helper function for prettier output
import json
def pprint(o):   
    print(json.dumps(o, indent=2))
    
pprint(interpreter.parse("is there any event on day after tomorrow ? "))
# Out:
# {
#   "intent": {
#     "name": "inform",
#     "confidence": 0.9514493346214294
#   },
#   "entities": [
#     {
#       "start": 13,
#       "end": 18,
#       "value": "event",
#       "entity": "events",
#       "confidence": 0.8445284086137127,
#       "extractor": "ner_crf"
#     },
#     {
#       "start": 32,
#       "end": 40,
#       "value": "tomorrow",
#       "entity": "time",
#       "confidence": 0.6096931036405927,
#       "extractor": "ner_crf"
#     },
#     {
#       "start": 19,
#       "end": 40,
#       "text": "on day after tomorrow",
#       "value": "2019-04-18T00:00:00.000-07:00",
#       "confidence": 1.0,
#       "additional_info": {
#         "values": [
#           {
#             "value": "2019-04-18T00:00:00.000-07:00",
#             "grain": "day",
#             "type": "value"
#           }
#         ],
#         "value": "2019-04-18T00:00:00.000-07:00",
#         "grain": "day",
#         "type": "value"
#       },
#       "entity": "time",
#       "extractor": "ner_duckling_http"
#     }
#   ],
#   "intent_ranking": [
#     {
#       "name": "inform",
#       "confidence": 0.9514493346214294
#     },
#     {
#       "name": "taxes",
#       "confidence": 0.1284797489643097
#     },
#     {
#       "name": "travel_date",
#       "confidence": 0.1176040917634964
#     },
#     {
#       "name": "course_registration",
#       "confidence": 0.08680985867977142
#     },
#     {
#       "name": "goodbye",
#       "confidence": 0.07170714437961578
#     },
#     {
#       "name": "greet",
#       "confidence": 0.06266845762729645
#     },
#     {
#       "name": "student_work",
#       "confidence": 0.04357322305440903
#     },
#     {
#       "name": "housing",
#       "confidence": 0.026980042457580566
#     },
#     {
#       "name": "student_work_timings",
#       "confidence": 0.022923722863197327
#     },
#     {
#       "name": "E_verify",
#       "confidence": 0.0
#     }
#   ],
#   "text": "is there any event on day after tomorrow ? "
# }

# %% [markdown]
# ## Evaluating the NLU model on a test data
# (Here we are using the data at hand i.e nlu.md but it isr recommended to use unseen data)

# %%
from rasa_nlu.evaluate import run_evaluation

run_evaluation("nlu.md", model_directory)
# Out:
# INFO:tensorflow:Restoring parameters from /Users/saching12/Desktop/python codes/student_assistant_chatbot/./models/nlu/default/current/intent_classifier_tensorflow_embedding.ckpt
# INFO:tensorflow:Restoring parameters from /Users/saching12/Desktop/python codes/student_assistant_chatbot/./models/nlu/default/current/intent_classifier_tensorflow_embedding.ckpt
# INFO:rasa_nlu.training_data.loading:Training data format of nlu.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 104 (20 distinct intents)
# 	- Found intents: 'student_work_timings', 'tution', 'questions_during_visa', 'E_verify', 'health_insurance', 'housing', 'student_work', 'greet', 'tower_ID', 'goodbye', 'travel_date', 'inform', 'student_work_authorization', 'course_registration', 'customs_immigration', 'taxes', 'immunization', 'mood_affirm', 'Visa_interview', 'mood_deny'
# 	- entity examples: 3 (2 distinct entities)
# 	- found entities: 'time', 'events'
#
# INFO:rasa_nlu.evaluate:Skipping evaluation of ner_duckling_http
# INFO:rasa_nlu.evaluate:Intent evaluation results:
# INFO:rasa_nlu.evaluate:Intent Evaluation: Only considering those 104 examples that have a defined intent out of 104 examples
# INFO:rasa_nlu.evaluate:F1-Score:  0.9904013377926422
# INFO:rasa_nlu.evaluate:Precision: 0.9911858974358974
# INFO:rasa_nlu.evaluate:Accuracy:  0.9903846153846154
# INFO:rasa_nlu.evaluate:Classification report:
#                             precision    recall  f1-score   support
#
#                   E_verify       1.00      1.00      1.00         6
#             Visa_interview       1.00      1.00      1.00         5
#        course_registration       1.00      1.00      1.00         4
#        customs_immigration       1.00      1.00      1.00         5
#                    goodbye       0.92      1.00      0.96        11
#                      greet       1.00      0.92      0.96        13
#           health_insurance       1.00      1.00      1.00         4
#                    housing       1.00      1.00      1.00         5
#               immunization       1.00      1.00      1.00         4
#                     inform       1.00      1.00      1.00         3
#                mood_affirm       1.00      1.00      1.00         5
#                  mood_deny       1.00      1.00      1.00         6
#      questions_during_visa       1.00      1.00      1.00         5
#               student_work       1.00      1.00      1.00         2
# student_work_authorization       1.00      1.00      1.00         5
#       student_work_timings       1.00      1.00      1.00         4
#                      taxes       1.00      1.00      1.00         4
#                   tower_ID       1.00      1.00      1.00         6
#                travel_date       1.00      1.00      1.00         2
#                     tution       1.00      1.00      1.00         5
#
#                  micro avg       0.99      0.99      0.99       104
#                  macro avg       1.00      1.00      1.00       104
#               weighted avg       0.99      0.99      0.99       104
#
# INFO:rasa_nlu.evaluate:Model prediction errors saved to errors.json.
# INFO:rasa_nlu.evaluate:Entity evaluation results:
# INFO:rasa_nlu.evaluate:Evaluation for entity extractor: ner_crf
# INFO:rasa_nlu.evaluate:F1-Score:  1.0
# INFO:rasa_nlu.evaluate:Precision: 1.0
# INFO:rasa_nlu.evaluate:Accuracy:  1.0
# INFO:rasa_nlu.evaluate:Classification report:
#               precision    recall  f1-score   support
#
#       events       1.00      1.00      1.00         3
#    no_entity       1.00      1.00      1.00       508
#         time       1.00      1.00      1.00         4
#
#    micro avg       1.00      1.00      1.00       515
#    macro avg       1.00      1.00      1.00       515
# weighted avg       1.00      1.00      1.00       515
# {'intent_evaluation': {'predictions': [{'text': 'hey',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.973138153553009},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9860146045684814},
#    {'text': 'hi',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9561765193939209},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9860146045684814},
#    {'text': 'good morning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9591532945632935},
#    {'text': 'good evening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9674699306488037},
#    {'text': 'moin',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9379739761352539},
#    {'text': 'hey there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.975002646446228},
#    {'text': "let's go",
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9830343723297119},
#    {'text': 'hey dude',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9789982438087463},
#    {'text': 'goodmorning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9691559076309204},
#    {'text': 'goodevening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.9840680360794067},
#    {'text': 'good afternoon',
#     'intent': 'greet',
#     'predicted': 'goodbye',
#     'confidence': 0.7764748334884644},
#    {'text': 'cu',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9548795819282532},
#    {'text': 'good by',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9709621667861938},
#    {'text': 'cee you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9595547914505005},
#    {'text': 'good night',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9608587622642517},
#    {'text': 'good afternoon',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.7764748334884644},
#    {'text': 'bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9452018141746521},
#    {'text': 'goodbye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9618390798568726},
#    {'text': 'have a nice day',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9615319967269897},
#    {'text': 'see you around',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9600214958190918},
#    {'text': 'bye bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9510228037834167},
#    {'text': 'see you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.9543901681900024},
#    {'text': 'yes',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9368335604667664},
#    {'text': 'indeed',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9318382740020752},
#    {'text': 'of course',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9482271075248718},
#    {'text': 'that sounds good',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9351584911346436},
#    {'text': 'correct',
#     'intent': 'mood_affirm',
#     'predicted': 'mood_affirm',
#     'confidence': 0.9470312595367432},
#    {'text': 'no',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.968540608882904},
#    {'text': 'never',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9564731121063232},
#    {'text': "I don't think so",
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9542437791824341},
#    {'text': "don't like that",
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9537277221679688},
#    {'text': 'no way',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.9680769443511963},
#    {'text': 'not really',
#     'intent': 'mood_deny',
#     'predicted': 'mood_deny',
#     'confidence': 0.966160774230957},
#    {'text': 'What does the student’s work authorization look like?',
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9516142010688782},
#    {'text': 'how is student work authorization?',
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9493733048439026},
#    {'text': 'how does student work authorization look like?',
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9606165289878845},
#    {'text': 'Student work authorization look?',
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9670748710632324},
#    {'text': "what's Student work authorization",
#     'intent': 'student_work_authorization',
#     'predicted': 'student_work_authorization',
#     'confidence': 0.9359463453292847},
#    {'text': 'When can a student work?',
#     'intent': 'student_work',
#     'predicted': 'student_work',
#     'confidence': 0.9504903554916382},
#    {'text': 'When can I work?',
#     'intent': 'student_work',
#     'predicted': 'student_work',
#     'confidence': 0.9439958930015564},
#    {'text': 'How many hours per week can a student work?',
#     'intent': 'student_work_timings',
#     'predicted': 'student_work_timings',
#     'confidence': 0.9457948207855225},
#    {'text': 'How many hours can I work?',
#     'intent': 'student_work_timings',
#     'predicted': 'student_work_timings',
#     'confidence': 0.9456073045730591},
#    {'text': 'number of hours I can work?',
#     'intent': 'student_work_timings',
#     'predicted': 'student_work_timings',
#     'confidence': 0.9552507400512695},
#    {'text': 'no. of hours I can work?',
#     'intent': 'student_work_timings',
#     'predicted': 'student_work_timings',
#     'confidence': 0.9509620070457458},
#    {'text': 'Are F-1 students subject to taxes?',
#     'intent': 'taxes',
#     'predicted': 'taxes',
#     'confidence': 0.9305429458618164},
#    {'text': 'am I subjected to tax ?',
#     'intent': 'taxes',
#     'predicted': 'taxes',
#     'confidence': 0.9197030067443848},
#    {'text': 'how much tax shoud I pay ?',
#     'intent': 'taxes',
#     'predicted': 'taxes',
#     'confidence': 0.9374423027038574},
#    {'text': 'should I pay tax ?',
#     'intent': 'taxes',
#     'predicted': 'taxes',
#     'confidence': 0.946576714515686},
#    {'text': 'What is E-Verify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9597821235656738},
#    {'text': 'how to do e-verify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9559515118598938},
#    {'text': 'What is E Verify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9597821235656738},
#    {'text': 'how to do e verify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9559515118598938},
#    {'text': 'What is EVerify?',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9572477340698242},
#    {'text': 'how to do everify',
#     'intent': 'E_verify',
#     'predicted': 'E_verify',
#     'confidence': 0.9649327397346497},
#    {'text': 'What all do I need for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9556837677955627},
#    {'text': 'what all documents do I need for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9506353139877319},
#    {'text': 'Documents needed for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9368568658828735},
#    {'text': 'What all things do I need for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9631407260894775},
#    {'text': 'What all papaers do I need for Visa Interview?',
#     'intent': 'Visa_interview',
#     'predicted': 'Visa_interview',
#     'confidence': 0.9460698366165161},
#    {'text': 'When can I travel to the usa?',
#     'intent': 'travel_date',
#     'predicted': 'travel_date',
#     'confidence': 0.9543439745903015},
#    {'text': 'How many days prior to my admission can I travel to the USA?',
#     'intent': 'travel_date',
#     'predicted': 'travel_date',
#     'confidence': 0.9318450689315796},
#    {'text': 'What all do I need for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9538171887397766},
#    {'text': 'what all documents do I need for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9542698264122009},
#    {'text': 'Documents needed for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9358595013618469},
#    {'text': 'What all things do I need for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9555742144584656},
#    {'text': 'What all papaers do I need for customs and immigration?',
#     'intent': 'customs_immigration',
#     'predicted': 'customs_immigration',
#     'confidence': 0.9533705711364746},
#    {'text': 'What are the common questions asked during Visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9726369380950928},
#    {'text': 'What should I prepare for Visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9819910526275635},
#    {'text': 'What kind of questions are asked during a visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9829100966453552},
#    {'text': 'Common questions durin Visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9621684551239014},
#    {'text': 'Questions asked in a Visa interview?',
#     'intent': 'questions_during_visa',
#     'predicted': 'questions_during_visa',
#     'confidence': 0.9689143300056458},
#    {'text': 'How do I pyrchase University heath insurance?',
#     'intent': 'health_insurance',
#     'predicted': 'health_insurance',
#     'confidence': 0.9550062417984009},
#    {'text': 'What steps are involved in purchasing student health insurance?',
#     'intent': 'health_insurance',
#     'predicted': 'health_insurance',
#     'confidence': 0.9551030397415161},
#    {'text': 'Steps to purchase health insurance?',
#     'intent': 'health_insurance',
#     'predicted': 'health_insurance',
#     'confidence': 0.9527547359466553},
#    {'text': 'international Heath Insurance puchase?',
#     'intent': 'health_insurance',
#     'predicted': 'health_insurance',
#     'confidence': 0.9581342339515686},
#    {'text': 'What are the steps involved in immunization?',
#     'intent': 'immunization',
#     'predicted': 'immunization',
#     'confidence': 0.9507384300231934},
#    {'text': 'What all immunization do I need before getting to the USA?',
#     'intent': 'immunization',
#     'predicted': 'immunization',
#     'confidence': 0.9616369605064392},
#    {'text': 'Kind of immunization required before reaching?',
#     'intent': 'immunization',
#     'predicted': 'immunization',
#     'confidence': 0.9647848606109619},
#    {'text': 'What is the proof of immunization that needs to be submitted?',
#     'intent': 'immunization',
#     'predicted': 'immunization',
#     'confidence': 0.9494877457618713},
#    {'text': 'Where can I find the housing details of SJSU?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9540249109268188},
#    {'text': 'Accomodation in SJSU?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9753168225288391},
#    {'text': 'Accomodation for international students at SJSU?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9679632186889648},
#    {'text': 'Housing for students near SJSU?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9585485458374023},
#    {'text': 'Housing on campus?',
#     'intent': 'housing',
#     'predicted': 'housing',
#     'confidence': 0.9726830124855042},
#    {'text': 'How many courses do I need to register for?',
#     'intent': 'course_registration',
#     'predicted': 'course_registration',
#     'confidence': 0.9672937393188477},
#    {'text': 'How many credits are mandatory?',
#     'intent': 'course_registration',
#     'predicted': 'course_registration',
#     'confidence': 0.9596669673919678},
#    {'text': 'Number of credits at SJSU?',
#     'intent': 'course_registration',
#     'predicted': 'course_registration',
#     'confidence': 0.941154420375824},
#    {'text': 'SJSU credits for F1 students?',
#     'intent': 'course_registration',
#     'predicted': 'course_registration',
#     'confidence': 0.9460643529891968},
#    {'text': 'Where can I find details about my tution fees?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.945049524307251},
#    {'text': 'Information about tution fees?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9536660313606262},
#    {'text': 'When do I have to pay for tution fees?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9564332365989685},
#    {'text': 'When can I register for the courses?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9505489468574524},
#    {'text': 'Where do I pay my tution?',
#     'intent': 'tution',
#     'predicted': 'tution',
#     'confidence': 0.9610264897346497},
#    {'text': 'Where can I get my ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9567214250564575},
#    {'text': 'Do I need an ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9625285863876343},
#    {'text': 'Procedure to get an ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9756735563278198},
#    {'text': 'Documents required to get an ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9720320105552673},
#    {'text': 'How do I get my student ID?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9672040939331055},
#    {'text': 'Steps involved in getting student ID card?',
#     'intent': 'tower_ID',
#     'predicted': 'tower_ID',
#     'confidence': 0.9518852233886719},
#    {'text': 'what event is happening tomorrow?',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9793328642845154},
#    {'text': 'do we have any event today?',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9770990014076233},
#    {'text': 'is there any event on 12th October?',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.9725266695022583}],
#   'report': '                            precision    recall  f1-score   support\n\n                  E_verify       1.00      1.00      1.00         6\n            Visa_interview       1.00      1.00      1.00         5\n       course_registration       1.00      1.00      1.00         4\n       customs_immigration       1.00      1.00      1.00         5\n                   goodbye       0.92      1.00      0.96        11\n                     greet       1.00      0.92      0.96        13\n          health_insurance       1.00      1.00      1.00         4\n                   housing       1.00      1.00      1.00         5\n              immunization       1.00      1.00      1.00         4\n                    inform       1.00      1.00      1.00         3\n               mood_affirm       1.00      1.00      1.00         5\n                 mood_deny       1.00      1.00      1.00         6\n     questions_during_visa       1.00      1.00      1.00         5\n              student_work       1.00      1.00      1.00         2\nstudent_work_authorization       1.00      1.00      1.00         5\n      student_work_timings       1.00      1.00      1.00         4\n                     taxes       1.00      1.00      1.00         4\n                  tower_ID       1.00      1.00      1.00         6\n               travel_date       1.00      1.00      1.00         2\n                    tution       1.00      1.00      1.00         5\n\n                 micro avg       0.99      0.99      0.99       104\n                 macro avg       1.00      1.00      1.00       104\n              weighted avg       0.99      0.99      0.99       104\n',
#   'precision': 0.9911858974358974,
#   'f1_score': 0.9904013377926422,
#   'accuracy': 0.9903846153846154},
#  'entity_evaluation': {'ner_crf': {'report': '              precision    recall  f1-score   support\n\n      events       1.00      1.00      1.00         3\n   no_entity       1.00      1.00      1.00       508\n        time       1.00      1.00      1.00         4\n\n   micro avg       1.00      1.00      1.00       515\n   macro avg       1.00      1.00      1.00       515\nweighted avg       1.00      1.00      1.00       515\n',
#    'precision': 1.0,
#    'f1_score': 1.0,
#    'accuracy': 1.0}}}

# %% [markdown]
# # 2. Teaching the bot to respond using Rasa Core

# %% [markdown]
# ## Custom Actions

# %%
from rasa_core.actions import Action
from rasa_core.events import SlotSet
from IPython.core.display import Image, display

import requests

class ApiAction(Action):
    def name(self):
        return "action_retrieve_event"

    def run(self, dispatcher, tracker, domain):
        
        time = tracker.get_slot('time')
        #date = time.split('T')[0]
        #print(date)
        #r = requests.get('http://shibe.online/api/{}?count=1&urls=true&httpsUrls=true'.format(time))
        #response = r.content.decode()
        #response = response.replace('["',"")
        #response = response.replace('"]',"")
   
        
        #display(Image(response[0], height=550, width=520))
        dispatcher.utter_message("Here is something to cheer you up: {}".format(time))

# %% [markdown]
# ##  Visualising the Training Data

# %% [markdown]
# ## Install these packages
# !apt-get -qq install -y graphviz libgraphviz-dev pkg-config;
# !breq install graphviz
#
# !{python} -m pip install pygraphviz;

# %%
from IPython.display import Image
from rasa_core.agent import Agent

agent = Agent('domain.yml')
agent.visualize("stories.md", "story_graph.png", max_history=2)
#Image(filename="story_graph.png")
# Out:
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 1067.07it/s, # trackers=1]
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 211007.08it/s]
# WARNING:rasa_core.training.generator:Unsatisfied end checkpoint 'goodbye_checkpoint' in block 'say goodbye'. Remove this checkpoint or add story blocks that start with this checkpoint.

# %%
config = """
policies:
  - name: "KerasPolicy"
    epochs: 700
    featurizer:
    - name: MaxHistoryTrackerFeaturizer
      max_history: 2
      state_featurizer:
        - name: BinarySingleStateFeaturizer
  - name: "MemoizationPolicy"
    max_history: 2
  - name: "FallbackPolicy"
    nlu_threshold: 0.5
    core_threshold: 0.2
    fallback_action_name: "utter_unclear"
""" 

# %store config > policy_config.yml
# Out:
# Writing 'config' (str) to file 'policy_config.yml'.

# %% [markdown]
# ## Training a Dialogue Model

# %%
from rasa_core.policies import FallbackPolicy, KerasPolicy, MemoizationPolicy
from rasa_core.agent import Agent
from rasa_core import config


agent = Agent('domain.yml', policies=config.load('policy_config.yml'))

# loading our neatly defined training dialogues
training_data = agent.load_data('stories.md')

agent.train(training_data)

agent.persist('models/dialogue')
# Out:
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 1172.56it/s, # trackers=1]
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 128290.20it/s]
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 468.54it/s, # trackers=6]
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 590.31it/s, # trackers=3]
# Processed Story Blocks: 100%|██████████| 49/49 [00:00<00:00, 525.83it/s, # trackers=4]
# WARNING:rasa_core.training.generator:Unsatisfied end checkpoint 'goodbye_checkpoint' in block 'say goodbye'. Remove this checkpoint or add story blocks that start with this checkpoint.
# INFO:rasa_core.policies.keras_policy:Fitting model with 196 total samples and a validation split of 0.1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 2, 57)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                11520
# _________________________________________________________________
# dense (Dense)                (None, 31)                1023
# _________________________________________________________________
# activation (Activation)      (None, 31)                0
# =================================================================
# Total params: 12,543
# Trainable params: 12,543
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/700
# 196/196 [==============================] - 1s 3ms/step - loss: 3.4235 - acc: 0.0510
# Epoch 2/700
# 196/196 [==============================] - 0s 124us/step - loss: 3.4011 - acc: 0.0969
# Epoch 3/700
# 196/196 [==============================] - 0s 128us/step - loss: 3.3849 - acc: 0.1531
# Epoch 4/700
# 196/196 [==============================] - 0s 121us/step - loss: 3.3688 - acc: 0.1378
# Epoch 5/700
# 196/196 [==============================] - 0s 119us/step - loss: 3.3518 - acc: 0.1582
# Epoch 6/700
# 196/196 [==============================] - 0s 119us/step - loss: 3.3306 - acc: 0.1837
# Epoch 7/700
# 196/196 [==============================] - 0s 123us/step - loss: 3.3166 - acc: 0.1633
# Epoch 8/700
# 196/196 [==============================] - 0s 115us/step - loss: 3.3017 - acc: 0.1582
# Epoch 9/700
# 196/196 [==============================] - 0s 127us/step - loss: 3.2801 - acc: 0.1735
# Epoch 10/700
# 196/196 [==============================] - 0s 123us/step - loss: 3.2591 - acc: 0.1378
# Epoch 11/700
# 196/196 [==============================] - 0s 133us/step - loss: 3.2452 - acc: 0.1531
# Epoch 12/700
# 196/196 [==============================] - 0s 122us/step - loss: 3.2062 - acc: 0.1633
# Epoch 13/700
# 196/196 [==============================] - 0s 128us/step - loss: 3.1884 - acc: 0.1684
# Epoch 14/700
# 196/196 [==============================] - 0s 122us/step - loss: 3.1653 - acc: 0.1735
# Epoch 15/700
# 196/196 [==============================] - 0s 127us/step - loss: 3.1246 - acc: 0.1633
# Epoch 16/700
# 196/196 [==============================] - 0s 124us/step - loss: 3.1072 - acc: 0.1531
# Epoch 17/700
# 196/196 [==============================] - 0s 126us/step - loss: 3.0694 - acc: 0.1633
# Epoch 18/700
# 196/196 [==============================] - 0s 127us/step - loss: 3.0516 - acc: 0.1582
# Epoch 19/700
# 196/196 [==============================] - 0s 127us/step - loss: 3.0148 - acc: 0.1531
# Epoch 20/700
# 196/196 [==============================] - 0s 134us/step - loss: 2.9930 - acc: 0.1633
# Epoch 21/700
# 196/196 [==============================] - 0s 118us/step - loss: 2.9628 - acc: 0.1480
# Epoch 22/700
# 196/196 [==============================] - 0s 131us/step - loss: 2.9337 - acc: 0.1480
# Epoch 23/700
# 196/196 [==============================] - 0s 135us/step - loss: 2.8922 - acc: 0.1531
# Epoch 24/700
# 196/196 [==============================] - 0s 129us/step - loss: 2.8838 - acc: 0.1531
# Epoch 25/700
# 196/196 [==============================] - 0s 126us/step - loss: 2.8520 - acc: 0.1531
# Epoch 26/700
# 196/196 [==============================] - 0s 126us/step - loss: 2.8168 - acc: 0.1531
# Epoch 27/700
# 196/196 [==============================] - 0s 119us/step - loss: 2.7800 - acc: 0.1480
# Epoch 28/700
# 196/196 [==============================] - 0s 127us/step - loss: 2.7390 - acc: 0.1582
# Epoch 29/700
# 196/196 [==============================] - 0s 128us/step - loss: 2.7207 - acc: 0.1633
# Epoch 30/700
# 196/196 [==============================] - 0s 129us/step - loss: 2.7082 - acc: 0.1633
# Epoch 31/700
# 196/196 [==============================] - 0s 123us/step - loss: 2.6668 - acc: 0.1684
# Epoch 32/700
# 196/196 [==============================] - 0s 125us/step - loss: 2.6424 - acc: 0.2041
# Epoch 33/700
# 196/196 [==============================] - 0s 128us/step - loss: 2.6375 - acc: 0.1684
# Epoch 34/700
# 196/196 [==============================] - 0s 127us/step - loss: 2.6012 - acc: 0.1990
# Epoch 35/700
# 196/196 [==============================] - 0s 127us/step - loss: 2.5816 - acc: 0.2296
# Epoch 36/700
# 196/196 [==============================] - 0s 125us/step - loss: 2.5363 - acc: 0.2449
# Epoch 37/700
# 196/196 [==============================] - 0s 131us/step - loss: 2.5007 - acc: 0.2449
# Epoch 38/700
# 196/196 [==============================] - 0s 122us/step - loss: 2.4848 - acc: 0.2755
# Epoch 39/700
# 196/196 [==============================] - 0s 130us/step - loss: 2.4493 - acc: 0.2704
# Epoch 40/700
# 196/196 [==============================] - 0s 124us/step - loss: 2.4316 - acc: 0.3061
# Epoch 41/700
# 196/196 [==============================] - 0s 123us/step - loss: 2.3943 - acc: 0.3265
# Epoch 42/700
# 196/196 [==============================] - 0s 133us/step - loss: 2.3650 - acc: 0.3163
# Epoch 43/700
# 196/196 [==============================] - 0s 129us/step - loss: 2.3590 - acc: 0.3929
# Epoch 44/700
# 196/196 [==============================] - 0s 125us/step - loss: 2.2948 - acc: 0.3980
# Epoch 45/700
# 196/196 [==============================] - 0s 135us/step - loss: 2.2866 - acc: 0.4286
# Epoch 46/700
# 196/196 [==============================] - 0s 124us/step - loss: 2.2315 - acc: 0.4745
# Epoch 47/700
# 196/196 [==============================] - 0s 126us/step - loss: 2.2056 - acc: 0.4541
# Epoch 48/700
# 196/196 [==============================] - 0s 118us/step - loss: 2.1632 - acc: 0.4949
# Epoch 49/700
# 196/196 [==============================] - 0s 125us/step - loss: 2.1313 - acc: 0.5306
# Epoch 50/700
# 196/196 [==============================] - 0s 130us/step - loss: 2.0824 - acc: 0.5102
# Epoch 51/700
# 196/196 [==============================] - 0s 124us/step - loss: 2.1018 - acc: 0.5408
# Epoch 52/700
# 196/196 [==============================] - 0s 126us/step - loss: 2.0502 - acc: 0.5663
# Epoch 53/700
# 196/196 [==============================] - 0s 119us/step - loss: 1.9880 - acc: 0.5918
# Epoch 54/700
# 196/196 [==============================] - 0s 130us/step - loss: 1.9684 - acc: 0.6276
# Epoch 55/700
# 196/196 [==============================] - 0s 127us/step - loss: 1.9281 - acc: 0.5969
# Epoch 56/700
# 196/196 [==============================] - 0s 127us/step - loss: 1.9037 - acc: 0.6276
# Epoch 57/700
# 196/196 [==============================] - 0s 119us/step - loss: 1.8428 - acc: 0.6224
# Epoch 58/700
# 196/196 [==============================] - 0s 128us/step - loss: 1.7748 - acc: 0.6531
# Epoch 59/700
# 196/196 [==============================] - 0s 124us/step - loss: 1.7478 - acc: 0.6684
# Epoch 60/700
# 196/196 [==============================] - 0s 132us/step - loss: 1.7529 - acc: 0.6582
# Epoch 61/700
# 196/196 [==============================] - 0s 119us/step - loss: 1.7144 - acc: 0.6480
# Epoch 62/700
# 196/196 [==============================] - 0s 121us/step - loss: 1.6603 - acc: 0.6480
# Epoch 63/700
# 196/196 [==============================] - 0s 129us/step - loss: 1.5999 - acc: 0.7245
# Epoch 64/700
# 196/196 [==============================] - 0s 127us/step - loss: 1.5858 - acc: 0.7245
# Epoch 65/700
# 196/196 [==============================] - 0s 130us/step - loss: 1.5828 - acc: 0.6378
# Epoch 66/700
# 196/196 [==============================] - 0s 124us/step - loss: 1.4805 - acc: 0.7398
# Epoch 67/700
# 196/196 [==============================] - 0s 131us/step - loss: 1.4488 - acc: 0.7704
# Epoch 68/700
# 196/196 [==============================] - 0s 125us/step - loss: 1.4474 - acc: 0.7704
# Epoch 69/700
# 196/196 [==============================] - 0s 120us/step - loss: 1.4626 - acc: 0.7194
# Epoch 70/700
# 196/196 [==============================] - 0s 132us/step - loss: 1.3837 - acc: 0.7653
# Epoch 71/700
# 196/196 [==============================] - 0s 128us/step - loss: 1.3244 - acc: 0.7755
# Epoch 72/700
# 196/196 [==============================] - 0s 126us/step - loss: 1.2993 - acc: 0.7806
# Epoch 73/700
# 196/196 [==============================] - 0s 126us/step - loss: 1.2710 - acc: 0.7806
# Epoch 74/700
# 196/196 [==============================] - 0s 122us/step - loss: 1.3152 - acc: 0.7857
# Epoch 75/700
# 196/196 [==============================] - 0s 124us/step - loss: 1.2777 - acc: 0.7857
# Epoch 76/700
# 196/196 [==============================] - 0s 127us/step - loss: 1.3360 - acc: 0.7245
# Epoch 77/700
# 196/196 [==============================] - 0s 118us/step - loss: 1.1566 - acc: 0.8112
# Epoch 78/700
# 196/196 [==============================] - 0s 124us/step - loss: 1.2019 - acc: 0.7806
# Epoch 79/700
# 196/196 [==============================] - 0s 123us/step - loss: 1.2278 - acc: 0.7092
# Epoch 80/700
# 196/196 [==============================] - 0s 127us/step - loss: 1.1023 - acc: 0.8316
# Epoch 81/700
# 196/196 [==============================] - 0s 121us/step - loss: 1.1577 - acc: 0.7959
# Epoch 82/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.9506 - acc: 0.8878
# Epoch 83/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.9884 - acc: 0.8367
# Epoch 84/700
# 196/196 [==============================] - 0s 130us/step - loss: 1.0679 - acc: 0.8163
# Epoch 85/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.9220 - acc: 0.8520
# Epoch 86/700
# 196/196 [==============================] - 0s 124us/step - loss: 1.0124 - acc: 0.8214
# Epoch 87/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.9453 - acc: 0.8418
# Epoch 88/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.9790 - acc: 0.8214
# Epoch 89/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.9430 - acc: 0.8214
# Epoch 90/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.9640 - acc: 0.8061
# Epoch 91/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.8630 - acc: 0.8469
# Epoch 92/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.8812 - acc: 0.8316
# Epoch 93/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.8533 - acc: 0.8112
# Epoch 94/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.9368 - acc: 0.8010
# Epoch 95/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.7458 - acc: 0.8724
# Epoch 96/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.7529 - acc: 0.8724
# Epoch 97/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.9007 - acc: 0.7959
# Epoch 98/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.8323 - acc: 0.8163
# Epoch 99/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.8240 - acc: 0.8367
# Epoch 100/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.7915 - acc: 0.8316
# Epoch 101/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.7902 - acc: 0.8418
# Epoch 102/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.6641 - acc: 0.9082
# Epoch 103/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.7962 - acc: 0.8163
# Epoch 104/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.7435 - acc: 0.8316
# Epoch 105/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.7402 - acc: 0.8418
# Epoch 106/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.6181 - acc: 0.8827
# Epoch 107/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.6837 - acc: 0.8469
# Epoch 108/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.6050 - acc: 0.8776
# Epoch 109/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.8009 - acc: 0.8010
# Epoch 110/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.6798 - acc: 0.8418
# Epoch 111/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.6686 - acc: 0.8520
# Epoch 112/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.5962 - acc: 0.8776
# Epoch 113/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.6675 - acc: 0.8469
# Epoch 114/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.6481 - acc: 0.8571
# Epoch 115/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.6081 - acc: 0.8724
# Epoch 116/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.6065 - acc: 0.8724
# Epoch 117/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.5150 - acc: 0.8878
# Epoch 118/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.5778 - acc: 0.8571
# Epoch 119/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.5294 - acc: 0.8776
# Epoch 120/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.6479 - acc: 0.8367
# Epoch 121/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.5222 - acc: 0.9031
# Epoch 122/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.6441 - acc: 0.8418
# Epoch 123/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.6455 - acc: 0.8367
# Epoch 124/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.7197 - acc: 0.8010
# Epoch 125/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.4947 - acc: 0.8878
# Epoch 126/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.6682 - acc: 0.8265
# Epoch 127/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.5399 - acc: 0.8520
# Epoch 128/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.4800 - acc: 0.8724
# Epoch 129/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.5962 - acc: 0.8214
# Epoch 130/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.5407 - acc: 0.8878
# Epoch 131/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.6033 - acc: 0.8418
# Epoch 132/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.5014 - acc: 0.8776
# Epoch 133/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.5970 - acc: 0.8469
# Epoch 134/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.4757 - acc: 0.8929
# Epoch 135/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.4360 - acc: 0.8878
# Epoch 136/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.5622 - acc: 0.8469
# Epoch 137/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.4389 - acc: 0.8776
# Epoch 138/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.4130 - acc: 0.9082
# Epoch 139/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.4261 - acc: 0.8929
# Epoch 140/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.3236 - acc: 0.9184
# Epoch 141/700
# 196/196 [==============================] - 0s 133us/step - loss: 0.4445 - acc: 0.8929
# Epoch 142/700
# 196/196 [==============================] - 0s 133us/step - loss: 0.4971 - acc: 0.8724
# Epoch 143/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.5169 - acc: 0.8980
# Epoch 144/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.3356 - acc: 0.9184
# Epoch 145/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.5488 - acc: 0.8265
# Epoch 146/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.4950 - acc: 0.8827
# Epoch 147/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.4505 - acc: 0.9031
# Epoch 148/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.6062 - acc: 0.8367
# Epoch 149/700
# 196/196 [==============================] - 0s 139us/step - loss: 0.5713 - acc: 0.8367
# Epoch 150/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.5504 - acc: 0.8469
# Epoch 151/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.5185 - acc: 0.8520
# Epoch 152/700
# 196/196 [==============================] - 0s 134us/step - loss: 0.6720 - acc: 0.8061
# Epoch 153/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.3995 - acc: 0.8776
# Epoch 154/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.5323 - acc: 0.8571
# Epoch 155/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.4476 - acc: 0.8827
# Epoch 156/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.5434 - acc: 0.8571
# Epoch 157/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.3833 - acc: 0.9031
# Epoch 158/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.4655 - acc: 0.8878
# Epoch 159/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.4496 - acc: 0.8724
# Epoch 160/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.4712 - acc: 0.8622
# Epoch 161/700
# 196/196 [==============================] - 0s 136us/step - loss: 0.4673 - acc: 0.8776
# Epoch 162/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.5961 - acc: 0.8316
# Epoch 163/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.6256 - acc: 0.8061
# Epoch 164/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.5739 - acc: 0.8418
# Epoch 165/700
# 196/196 [==============================] - 0s 139us/step - loss: 0.3646 - acc: 0.9133
# Epoch 166/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.4379 - acc: 0.8878
# Epoch 167/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.4934 - acc: 0.8571
# Epoch 168/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.3017 - acc: 0.9235
# Epoch 169/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.3734 - acc: 0.9082
# Epoch 170/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.3836 - acc: 0.8980
# Epoch 171/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.4336 - acc: 0.8776
# Epoch 172/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3820 - acc: 0.8980
# Epoch 173/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.4859 - acc: 0.8571
# Epoch 174/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.3311 - acc: 0.9184
# Epoch 175/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.4973 - acc: 0.8673
# Epoch 176/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.5063 - acc: 0.8418
# Epoch 177/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.5728 - acc: 0.8316
# Epoch 178/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.4826 - acc: 0.8724
# Epoch 179/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.3339 - acc: 0.9286
# Epoch 180/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.4140 - acc: 0.8776
# Epoch 181/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.4504 - acc: 0.8673
# Epoch 182/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.3642 - acc: 0.8980
# Epoch 183/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.4046 - acc: 0.8929
# Epoch 184/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.5813 - acc: 0.8316
# Epoch 185/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.4604 - acc: 0.8827
# Epoch 186/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.3803 - acc: 0.8929
# Epoch 187/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3483 - acc: 0.9184
# Epoch 188/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.4705 - acc: 0.8571
# Epoch 189/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.4632 - acc: 0.8776
# Epoch 190/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.5027 - acc: 0.8673
# Epoch 191/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.3763 - acc: 0.9286
# Epoch 192/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.3027 - acc: 0.9337
# Epoch 193/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.5128 - acc: 0.8673
# Epoch 194/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.4032 - acc: 0.9184
# Epoch 195/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.3911 - acc: 0.9031
# Epoch 196/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.4753 - acc: 0.8673
# Epoch 197/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.4040 - acc: 0.9031
# Epoch 198/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.4025 - acc: 0.9133
# Epoch 199/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.3652 - acc: 0.9286
# Epoch 200/700
# 196/196 [==============================] - 0s 134us/step - loss: 0.4606 - acc: 0.8929
# Epoch 201/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.3251 - acc: 0.9235
# Epoch 202/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.4408 - acc: 0.9031
# Epoch 203/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.3309 - acc: 0.9286
# Epoch 204/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.2767 - acc: 0.9286
# Epoch 205/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.3664 - acc: 0.8980
# Epoch 206/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.3603 - acc: 0.9235
# Epoch 207/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.5361 - acc: 0.8673
# Epoch 208/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.3337 - acc: 0.9133
# Epoch 209/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.3986 - acc: 0.8980
# Epoch 210/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.4283 - acc: 0.8827
# Epoch 211/700
# 196/196 [==============================] - 0s 133us/step - loss: 0.4271 - acc: 0.8827
# Epoch 212/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.3872 - acc: 0.8980
# Epoch 213/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.3697 - acc: 0.8980
# Epoch 214/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.3789 - acc: 0.9031
# Epoch 215/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.4130 - acc: 0.9082
# Epoch 216/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.5143 - acc: 0.8520
# Epoch 217/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.3508 - acc: 0.9082
# Epoch 218/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.3123 - acc: 0.9235
# Epoch 219/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.4631 - acc: 0.9031
# Epoch 220/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.3019 - acc: 0.9388
# Epoch 221/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.2162 - acc: 0.9643
# Epoch 222/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.3115 - acc: 0.9286
# Epoch 223/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.3773 - acc: 0.9031
# Epoch 224/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.3274 - acc: 0.9184
# Epoch 225/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.3474 - acc: 0.9082
# Epoch 226/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.4375 - acc: 0.8776
# Epoch 227/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.4457 - acc: 0.8980
# Epoch 228/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.3804 - acc: 0.9133
# Epoch 229/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.3625 - acc: 0.9235
# Epoch 230/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.3526 - acc: 0.9337
# Epoch 231/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.3220 - acc: 0.9031
# Epoch 232/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.4114 - acc: 0.9082
# Epoch 233/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.3185 - acc: 0.9439
# Epoch 234/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.2656 - acc: 0.9490
# Epoch 235/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.4946 - acc: 0.8929
# Epoch 236/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.2861 - acc: 0.9439
# Epoch 237/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.3839 - acc: 0.9082
# Epoch 238/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.3378 - acc: 0.9184
# Epoch 239/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.3248 - acc: 0.9592
# Epoch 240/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.3247 - acc: 0.9439
# Epoch 241/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.4380 - acc: 0.9082
# Epoch 242/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.3164 - acc: 0.9592
# Epoch 243/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.2759 - acc: 0.9592
# Epoch 244/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3844 - acc: 0.9133
# Epoch 245/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.3767 - acc: 0.9031
# Epoch 246/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.3270 - acc: 0.9337
# Epoch 247/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.3517 - acc: 0.9184
# Epoch 248/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.3805 - acc: 0.9286
# Epoch 249/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.3076 - acc: 0.9490
# Epoch 250/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.3508 - acc: 0.9337
# Epoch 251/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3277 - acc: 0.9439
# Epoch 252/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3922 - acc: 0.9133
# Epoch 253/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.2915 - acc: 0.9643
# Epoch 254/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3924 - acc: 0.9133
# Epoch 255/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.3638 - acc: 0.9082
# Epoch 256/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.2823 - acc: 0.9388
# Epoch 257/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.4043 - acc: 0.9031
# Epoch 258/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.3410 - acc: 0.9286
# Epoch 259/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.3486 - acc: 0.9337
# Epoch 260/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.3889 - acc: 0.9388
# Epoch 261/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2989 - acc: 0.9490
# Epoch 262/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.3475 - acc: 0.9235
# Epoch 263/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3605 - acc: 0.9184
# Epoch 264/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.3286 - acc: 0.9490
# Epoch 265/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.3331 - acc: 0.9337
# Epoch 266/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.3831 - acc: 0.9133
# Epoch 267/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.3766 - acc: 0.9439
# Epoch 268/700
# 196/196 [==============================] - 0s 113us/step - loss: 0.4281 - acc: 0.9286
# Epoch 269/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.2878 - acc: 0.9439
# Epoch 270/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.2886 - acc: 0.9490
# Epoch 271/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.3046 - acc: 0.9592
# Epoch 272/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.3968 - acc: 0.9337
# Epoch 273/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.3018 - acc: 0.9694
# Epoch 274/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.4057 - acc: 0.9235
# Epoch 275/700
# 196/196 [==============================] - 0s 112us/step - loss: 0.3220 - acc: 0.9490
# Epoch 276/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.2850 - acc: 0.9490
# Epoch 277/700
# 196/196 [==============================] - 0s 112us/step - loss: 0.3286 - acc: 0.9439
# Epoch 278/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2646 - acc: 0.9694
# Epoch 279/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.3566 - acc: 0.9337
# Epoch 280/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.3024 - acc: 0.9439
# Epoch 281/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.3109 - acc: 0.9541
# Epoch 282/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.3759 - acc: 0.9184
# Epoch 283/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.4299 - acc: 0.9031
# Epoch 284/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2817 - acc: 0.9439
# Epoch 285/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2524 - acc: 0.9490
# Epoch 286/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.2920 - acc: 0.9643
# Epoch 287/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2946 - acc: 0.9388
# Epoch 288/700
# 196/196 [==============================] - 0s 111us/step - loss: 0.4344 - acc: 0.8980
# Epoch 289/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.3048 - acc: 0.9490
# Epoch 290/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2321 - acc: 0.9643
# Epoch 291/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3586 - acc: 0.9439
# Epoch 292/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.3157 - acc: 0.9541
# Epoch 293/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.3438 - acc: 0.9439
# Epoch 294/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.3716 - acc: 0.9439
# Epoch 295/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.2712 - acc: 0.9439
# Epoch 296/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.2859 - acc: 0.9541
# Epoch 297/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2808 - acc: 0.9286
# Epoch 298/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.2997 - acc: 0.9235
# Epoch 299/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2507 - acc: 0.9337
# Epoch 300/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.2094 - acc: 0.9796
# Epoch 301/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.4132 - acc: 0.9031
# Epoch 302/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.3053 - acc: 0.9337
# Epoch 303/700
# 196/196 [==============================] - 0s 160us/step - loss: 0.2272 - acc: 0.9592
# Epoch 304/700
# 196/196 [==============================] - 0s 171us/step - loss: 0.2351 - acc: 0.9745
# Epoch 305/700
# 196/196 [==============================] - 0s 156us/step - loss: 0.3324 - acc: 0.9541
# Epoch 306/700
# 196/196 [==============================] - 0s 152us/step - loss: 0.3338 - acc: 0.9541
# Epoch 307/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.3140 - acc: 0.9439
# Epoch 308/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2264 - acc: 0.9694
# Epoch 309/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.2231 - acc: 0.9796
# Epoch 310/700
# 196/196 [==============================] - 0s 140us/step - loss: 0.2952 - acc: 0.9490
# Epoch 311/700
# 196/196 [==============================] - 0s 133us/step - loss: 0.2793 - acc: 0.9796
# Epoch 312/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.2945 - acc: 0.9490
# Epoch 313/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.3097 - acc: 0.9490
# Epoch 314/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2446 - acc: 0.9796
# Epoch 315/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.2192 - acc: 0.9643
# Epoch 316/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.3094 - acc: 0.9694
# Epoch 317/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2864 - acc: 0.9541
# Epoch 318/700
# 196/196 [==============================] - 0s 146us/step - loss: 0.3418 - acc: 0.9490
# Epoch 319/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.2531 - acc: 0.9643
# Epoch 320/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.2844 - acc: 0.9490
# Epoch 321/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.2428 - acc: 0.9592
# Epoch 322/700
# 196/196 [==============================] - 0s 138us/step - loss: 0.3002 - acc: 0.9490
# Epoch 323/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.2387 - acc: 0.9592
# Epoch 324/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2459 - acc: 0.9490
# Epoch 325/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.2009 - acc: 0.9694
# Epoch 326/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.2370 - acc: 0.9541
# Epoch 327/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2817 - acc: 0.9541
# Epoch 328/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.2242 - acc: 0.9643
# Epoch 329/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.2686 - acc: 0.9643
# Epoch 330/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.2683 - acc: 0.9490
# Epoch 331/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.1735 - acc: 0.9796
# Epoch 332/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.3119 - acc: 0.9337
# Epoch 333/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2194 - acc: 0.9541
# Epoch 334/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2805 - acc: 0.9490
# Epoch 335/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.2219 - acc: 0.9592
# Epoch 336/700
# 196/196 [==============================] - 0s 136us/step - loss: 0.2473 - acc: 0.9643
# Epoch 337/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.2431 - acc: 0.9643
# Epoch 338/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.2339 - acc: 0.9643
# Epoch 339/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.3355 - acc: 0.9643
# Epoch 340/700
# 196/196 [==============================] - 0s 141us/step - loss: 0.2769 - acc: 0.9541
# Epoch 341/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.2663 - acc: 0.9541
# Epoch 342/700
# 196/196 [==============================] - 0s 134us/step - loss: 0.2234 - acc: 0.9745
# Epoch 343/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.2264 - acc: 0.9745
# Epoch 344/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.2486 - acc: 0.9745
# Epoch 345/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.3715 - acc: 0.9439
# Epoch 346/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.2352 - acc: 0.9541
# Epoch 347/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.3228 - acc: 0.9337
# Epoch 348/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2423 - acc: 0.9694
# Epoch 349/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.2690 - acc: 0.9541
# Epoch 350/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.2006 - acc: 0.9694
# Epoch 351/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1941 - acc: 0.9847
# Epoch 352/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.2360 - acc: 0.9490
# Epoch 353/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.1823 - acc: 0.9592
# Epoch 354/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.3004 - acc: 0.9490
# Epoch 355/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.1754 - acc: 0.9745
# Epoch 356/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2132 - acc: 0.9745
# Epoch 357/700
# 196/196 [==============================] - 0s 137us/step - loss: 0.2308 - acc: 0.9694
# Epoch 358/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.2405 - acc: 0.9490
# Epoch 359/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.1478 - acc: 0.9949
# Epoch 360/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.2948 - acc: 0.9337
# Epoch 361/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.3165 - acc: 0.9388
# Epoch 362/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.2304 - acc: 0.9694
# Epoch 363/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.3153 - acc: 0.9490
# Epoch 364/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2554 - acc: 0.9439
# Epoch 365/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.2357 - acc: 0.9643
# Epoch 366/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.1688 - acc: 0.9796
# Epoch 367/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.1841 - acc: 0.9745
# Epoch 368/700
# 196/196 [==============================] - 0s 133us/step - loss: 0.2480 - acc: 0.9439
# Epoch 369/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.1944 - acc: 0.9643
# Epoch 370/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.3555 - acc: 0.9439
# Epoch 371/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.1914 - acc: 0.9745
# Epoch 372/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.2651 - acc: 0.9694
# Epoch 373/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2120 - acc: 0.9643
# Epoch 374/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1903 - acc: 0.9694
# Epoch 375/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.2307 - acc: 0.9694
# Epoch 376/700
# 196/196 [==============================] - 0s 138us/step - loss: 0.2209 - acc: 0.9592
# Epoch 377/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1753 - acc: 0.9643
# Epoch 378/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2423 - acc: 0.9490
# Epoch 379/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.1694 - acc: 0.9847
# Epoch 380/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.2247 - acc: 0.9643
# Epoch 381/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2751 - acc: 0.9388
# Epoch 382/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.1617 - acc: 0.9796
# Epoch 383/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.2517 - acc: 0.9694
# Epoch 384/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.1699 - acc: 0.9796
# Epoch 385/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.1631 - acc: 0.9694
# Epoch 386/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.1671 - acc: 0.9745
# Epoch 387/700
# 196/196 [==============================] - 0s 138us/step - loss: 0.2052 - acc: 0.9796
# Epoch 388/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1849 - acc: 0.9847
# Epoch 389/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.2446 - acc: 0.9541
# Epoch 390/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.2601 - acc: 0.9490
# Epoch 391/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.1553 - acc: 0.9796
# Epoch 392/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.1779 - acc: 0.9796
# Epoch 393/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.1822 - acc: 0.9949
# Epoch 394/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.2267 - acc: 0.9694
# Epoch 395/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.2006 - acc: 0.9796
# Epoch 396/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1776 - acc: 0.9694
# Epoch 397/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.1959 - acc: 0.9694
# Epoch 398/700
# 196/196 [==============================] - 0s 149us/step - loss: 0.2223 - acc: 0.9745
# Epoch 399/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1444 - acc: 0.9847
# Epoch 400/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.2550 - acc: 0.9541
# Epoch 401/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.2198 - acc: 0.9541
# Epoch 402/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1957 - acc: 0.9541
# Epoch 403/700
# 196/196 [==============================] - 0s 145us/step - loss: 0.1443 - acc: 0.9847
# Epoch 404/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1814 - acc: 0.9694
# Epoch 405/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.1846 - acc: 0.9643
# Epoch 406/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.2030 - acc: 0.9694
# Epoch 407/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2115 - acc: 0.9541
# Epoch 408/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.2115 - acc: 0.9745
# Epoch 409/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.1648 - acc: 0.9694
# Epoch 410/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.2580 - acc: 0.9337
# Epoch 411/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.1918 - acc: 0.9592
# Epoch 412/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.2231 - acc: 0.9541
# Epoch 413/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.2055 - acc: 0.9541
# Epoch 414/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.2909 - acc: 0.9286
# Epoch 415/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2497 - acc: 0.9490
# Epoch 416/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1533 - acc: 0.9796
# Epoch 417/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1739 - acc: 0.9745
# Epoch 418/700
# 196/196 [==============================] - 0s 137us/step - loss: 0.2042 - acc: 0.9541
# Epoch 419/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.2209 - acc: 0.9592
# Epoch 420/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1408 - acc: 0.9847
# Epoch 421/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1886 - acc: 0.9643
# Epoch 422/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.2454 - acc: 0.9388
# Epoch 423/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.2122 - acc: 0.9490
# Epoch 424/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.2114 - acc: 0.9592
# Epoch 425/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2125 - acc: 0.9643
# Epoch 426/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.2109 - acc: 0.9439
# Epoch 427/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2150 - acc: 0.9592
# Epoch 428/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.2309 - acc: 0.9643
# Epoch 429/700
# 196/196 [==============================] - 0s 136us/step - loss: 0.1596 - acc: 0.9694
# Epoch 430/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.2810 - acc: 0.9337
# Epoch 431/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.2118 - acc: 0.9490
# Epoch 432/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1756 - acc: 0.9847
# Epoch 433/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.2085 - acc: 0.9541
# Epoch 434/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2735 - acc: 0.9439
# Epoch 435/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.2230 - acc: 0.9490
# Epoch 436/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.1791 - acc: 0.9745
# Epoch 437/700
# 196/196 [==============================] - 0s 135us/step - loss: 0.1272 - acc: 0.9847
# Epoch 438/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2934 - acc: 0.9235
# Epoch 439/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1504 - acc: 0.9694
# Epoch 440/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.2194 - acc: 0.9541
# Epoch 441/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1867 - acc: 0.9694
# Epoch 442/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.1774 - acc: 0.9745
# Epoch 443/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.1659 - acc: 0.9796
# Epoch 444/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1512 - acc: 0.9796
# Epoch 445/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1292 - acc: 0.9796
# Epoch 446/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1074 - acc: 0.9949
# Epoch 447/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.1802 - acc: 0.9643
# Epoch 448/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.1271 - acc: 0.9796
# Epoch 449/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.1784 - acc: 0.9592
# Epoch 450/700
# 196/196 [==============================] - 0s 148us/step - loss: 0.1365 - acc: 0.9745
# Epoch 451/700
# 196/196 [==============================] - 0s 136us/step - loss: 0.1787 - acc: 0.9643
# Epoch 452/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.2057 - acc: 0.9694
# Epoch 453/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1801 - acc: 0.9643
# Epoch 454/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.1157 - acc: 0.9847
# Epoch 455/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0793 - acc: 0.9949
# Epoch 456/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1538 - acc: 0.9643
# Epoch 457/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1905 - acc: 0.9694
# Epoch 458/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1294 - acc: 0.9694
# Epoch 459/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1612 - acc: 0.9643
# Epoch 460/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1814 - acc: 0.9643
# Epoch 461/700
# 196/196 [==============================] - 0s 137us/step - loss: 0.2060 - acc: 0.9643
# Epoch 462/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.1156 - acc: 0.9796
# Epoch 463/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.2274 - acc: 0.9388
# Epoch 464/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.1787 - acc: 0.9694
# Epoch 465/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.2061 - acc: 0.9643
# Epoch 466/700
# ...
# Epoch 545/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1485 - acc: 0.9796
# Epoch 546/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1513 - acc: 0.9694
# Epoch 547/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.1624 - acc: 0.9592
# Epoch 548/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.1658 - acc: 0.9439
# Epoch 549/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1485 - acc: 0.9643
# Epoch 550/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1237 - acc: 0.9898
# Epoch 551/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.0716 - acc: 0.9898
# Epoch 552/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.1864 - acc: 0.9541
# Epoch 553/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0738 - acc: 0.9898
# Epoch 554/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.1308 - acc: 0.9643
# Epoch 555/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1534 - acc: 0.9541
# Epoch 556/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.0805 - acc: 0.9847
# Epoch 557/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0851 - acc: 0.9745
# Epoch 558/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.0945 - acc: 0.9694
# Epoch 559/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1784 - acc: 0.9490
# Epoch 560/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.0689 - acc: 0.9898
# Epoch 561/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.1171 - acc: 0.9643
# Epoch 562/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1344 - acc: 0.9745
# Epoch 563/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1181 - acc: 0.9643
# Epoch 564/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.0908 - acc: 0.9796
# Epoch 565/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.0886 - acc: 0.9796
# Epoch 566/700
# 196/196 [==============================] - 0s 134us/step - loss: 0.1641 - acc: 0.9694
# Epoch 567/700
# 196/196 [==============================] - 0s 139us/step - loss: 0.1781 - acc: 0.9490
# Epoch 568/700
# 196/196 [==============================] - 0s 134us/step - loss: 0.1073 - acc: 0.9643
# Epoch 569/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.1221 - acc: 0.9745
# Epoch 570/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.0614 - acc: 0.9949
# Epoch 571/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1558 - acc: 0.9541
# Epoch 572/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1527 - acc: 0.9541
# Epoch 573/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.0584 - acc: 0.9898
# Epoch 574/700
# 196/196 [==============================] - 0s 129us/step - loss: 0.1354 - acc: 0.9694
# Epoch 575/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1357 - acc: 0.9643
# Epoch 576/700
# 196/196 [==============================] - 0s 137us/step - loss: 0.1100 - acc: 0.9745
# Epoch 577/700
# 196/196 [==============================] - 0s 133us/step - loss: 0.0846 - acc: 0.9745
# Epoch 578/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.0860 - acc: 0.9745
# Epoch 579/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.1241 - acc: 0.9796
# Epoch 580/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.0906 - acc: 0.9745
# Epoch 581/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1158 - acc: 0.9694
# Epoch 582/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.0932 - acc: 0.9745
# Epoch 583/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.0864 - acc: 0.9796
# Epoch 584/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.0906 - acc: 0.9694
# Epoch 585/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.0826 - acc: 0.9847
# Epoch 586/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.0900 - acc: 0.9694
# Epoch 587/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.1548 - acc: 0.9541
# Epoch 588/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1478 - acc: 0.9592
# Epoch 589/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.1051 - acc: 0.9694
# Epoch 590/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.1229 - acc: 0.9694
# Epoch 591/700
# 196/196 [==============================] - 0s 147us/step - loss: 0.1471 - acc: 0.9643
# Epoch 592/700
# 196/196 [==============================] - 0s 143us/step - loss: 0.1169 - acc: 0.9694
# Epoch 593/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1681 - acc: 0.9541
# Epoch 594/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.1220 - acc: 0.9643
# Epoch 595/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.0626 - acc: 0.9898
# Epoch 596/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.0613 - acc: 0.9898
# Epoch 597/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.1433 - acc: 0.9592
# Epoch 598/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.1430 - acc: 0.9490
# Epoch 599/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1294 - acc: 0.9643
# Epoch 600/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.0551 - acc: 0.9898
# Epoch 601/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.1404 - acc: 0.9694
# Epoch 602/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1305 - acc: 0.9643
# Epoch 603/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1078 - acc: 0.9745
# Epoch 604/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1161 - acc: 0.9745
# Epoch 605/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1647 - acc: 0.9490
# Epoch 606/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.1124 - acc: 0.9694
# Epoch 607/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.1389 - acc: 0.9643
# Epoch 608/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0840 - acc: 0.9847
# Epoch 609/700
# 196/196 [==============================] - 0s 136us/step - loss: 0.1042 - acc: 0.9694
# Epoch 610/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.1572 - acc: 0.9592
# Epoch 611/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0981 - acc: 0.9745
# Epoch 612/700
# 196/196 [==============================] - 0s 133us/step - loss: 0.1071 - acc: 0.9796
# Epoch 613/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.1143 - acc: 0.9694
# Epoch 614/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0849 - acc: 0.9643
# Epoch 615/700
# 196/196 [==============================] - 0s 112us/step - loss: 0.0363 - acc: 0.9898
# Epoch 616/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.0911 - acc: 0.9745
# Epoch 617/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.0467 - acc: 0.9847
# Epoch 618/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.1082 - acc: 0.9796
# Epoch 619/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1262 - acc: 0.9796
# Epoch 620/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.0792 - acc: 0.9745
# Epoch 621/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.0936 - acc: 0.9694
# Epoch 622/700
# 196/196 [==============================] - 0s 126us/step - loss: 0.1239 - acc: 0.9592
# Epoch 623/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.1200 - acc: 0.9694
# Epoch 624/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.1353 - acc: 0.9592
# Epoch 625/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.0738 - acc: 0.9847
# Epoch 626/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.1147 - acc: 0.9694
# Epoch 627/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.1086 - acc: 0.9745
# Epoch 628/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.1314 - acc: 0.9694
# Epoch 629/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.0789 - acc: 0.9745
# Epoch 630/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.1019 - acc: 0.9796
# Epoch 631/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.0756 - acc: 0.9745
# Epoch 632/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.1028 - acc: 0.9745
# Epoch 633/700
# 196/196 [==============================] - 0s 114us/step - loss: 0.1022 - acc: 0.9745
# Epoch 634/700
# 196/196 [==============================] - 0s 114us/step - loss: 0.0673 - acc: 0.9847
# Epoch 635/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.0421 - acc: 0.9898
# Epoch 636/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.0559 - acc: 0.9949
# Epoch 637/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.0915 - acc: 0.9847
# Epoch 638/700
# 196/196 [==============================] - 0s 112us/step - loss: 0.0443 - acc: 0.9898
# Epoch 639/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.0834 - acc: 0.9796
# Epoch 640/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.0755 - acc: 0.9694
# Epoch 641/700
# 196/196 [==============================] - 0s 113us/step - loss: 0.0983 - acc: 0.9745
# Epoch 642/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.0719 - acc: 0.9898
# Epoch 643/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.0783 - acc: 0.9796
# Epoch 644/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.1235 - acc: 0.9643
# Epoch 645/700
# 196/196 [==============================] - 0s 114us/step - loss: 0.0951 - acc: 0.9847
# Epoch 646/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.0843 - acc: 0.9694
# Epoch 647/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.0927 - acc: 0.9745
# Epoch 648/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.0863 - acc: 0.9745
# Epoch 649/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0771 - acc: 0.9796
# Epoch 650/700
# 196/196 [==============================] - 0s 130us/step - loss: 0.0573 - acc: 1.0000
# Epoch 651/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.0776 - acc: 0.9796
# Epoch 652/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.0496 - acc: 0.9898
# Epoch 653/700
# 196/196 [==============================] - 0s 120us/step - loss: 0.0604 - acc: 0.9898
# Epoch 654/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.0843 - acc: 0.9796
# Epoch 655/700
# 196/196 [==============================] - 0s 128us/step - loss: 0.0328 - acc: 0.9898
# Epoch 656/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1742 - acc: 0.9541
# Epoch 657/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.0655 - acc: 0.9847
# Epoch 658/700
# 196/196 [==============================] - 0s 131us/step - loss: 0.1201 - acc: 0.9643
# Epoch 659/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.2030 - acc: 0.9388
# Epoch 660/700
# 196/196 [==============================] - 0s 133us/step - loss: 0.1628 - acc: 0.9541
# Epoch 661/700
# 196/196 [==============================] - 0s 124us/step - loss: 0.0968 - acc: 0.9745
# Epoch 662/700
# 196/196 [==============================] - 0s 132us/step - loss: 0.1101 - acc: 0.9796
# Epoch 663/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1325 - acc: 0.9592
# Epoch 664/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.0703 - acc: 0.9796
# Epoch 665/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0471 - acc: 0.9949
# Epoch 666/700
# 196/196 [==============================] - 0s 137us/step - loss: 0.0920 - acc: 0.9643
# Epoch 667/700
# 196/196 [==============================] - 0s 127us/step - loss: 0.0743 - acc: 0.9796
# Epoch 668/700
# 196/196 [==============================] - 0s 125us/step - loss: 0.0750 - acc: 0.9796
# Epoch 669/700
# 196/196 [==============================] - 0s 122us/step - loss: 0.1048 - acc: 0.9745
# Epoch 670/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.1047 - acc: 0.9694
# Epoch 671/700
# 196/196 [==============================] - 0s 113us/step - loss: 0.1696 - acc: 0.9439
# Epoch 672/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.1326 - acc: 0.9643
# Epoch 673/700
# 196/196 [==============================] - 0s 113us/step - loss: 0.1067 - acc: 0.9796
# Epoch 674/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.0979 - acc: 0.9694
# Epoch 675/700
# 196/196 [==============================] - 0s 112us/step - loss: 0.1522 - acc: 0.9541
# Epoch 676/700
# 196/196 [==============================] - 0s 110us/step - loss: 0.0712 - acc: 0.9847
# Epoch 677/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.0705 - acc: 0.9898
# Epoch 678/700
# 196/196 [==============================] - 0s 113us/step - loss: 0.0805 - acc: 0.9796
# Epoch 679/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.0541 - acc: 0.9949
# Epoch 680/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.1139 - acc: 0.9745
# Epoch 681/700
# 196/196 [==============================] - 0s 110us/step - loss: 0.0785 - acc: 0.9898
# Epoch 682/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.0948 - acc: 0.9745
# Epoch 683/700
# 196/196 [==============================] - 0s 117us/step - loss: 0.0945 - acc: 0.9847
# Epoch 684/700
# 196/196 [==============================] - 0s 113us/step - loss: 0.0822 - acc: 0.9796
# Epoch 685/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.0637 - acc: 0.9847
# Epoch 686/700
# 196/196 [==============================] - 0s 113us/step - loss: 0.0606 - acc: 0.9745
# Epoch 687/700
# 196/196 [==============================] - 0s 118us/step - loss: 0.0654 - acc: 0.9847
# Epoch 688/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.0757 - acc: 0.9796
# Epoch 689/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.1109 - acc: 0.9643
# Epoch 690/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.0685 - acc: 0.9847
# Epoch 691/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.0934 - acc: 0.9694
# Epoch 692/700
# 196/196 [==============================] - 0s 119us/step - loss: 0.0989 - acc: 0.9694
# Epoch 693/700
# 196/196 [==============================] - 0s 110us/step - loss: 0.1248 - acc: 0.9541
# Epoch 694/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.1300 - acc: 0.9643
# Epoch 695/700
# 196/196 [==============================] - 0s 113us/step - loss: 0.1374 - acc: 0.9541
# Epoch 696/700
# 196/196 [==============================] - 0s 111us/step - loss: 0.0988 - acc: 0.9745
# Epoch 697/700
# 196/196 [==============================] - 0s 116us/step - loss: 0.1426 - acc: 0.9694
# Epoch 698/700
# 196/196 [==============================] - 0s 115us/step - loss: 0.0590 - acc: 0.9847
# Epoch 699/700
# 196/196 [==============================] - 0s 123us/step - loss: 0.0975 - acc: 0.9694
# Epoch 700/700
# 196/196 [==============================] - 0s 121us/step - loss: 0.1209 - acc: 0.9796
# INFO:rasa_core.policies.keras_policy:Done fitting keras policy model
# Processed actions: 196it [00:00, 1496.58it/s, # examples=196]
# INFO:rasa_core.agent:Model directory models/dialogue exists and contains old model files. All files will be overwritten.
# INFO:rasa_core.agent:Persisted model to '/Users/saching12/Desktop/python codes/student_assistant_chatbot/models/dialogue'

# %% [markdown]
# # Talk to your Bot

# %%
#Starting the Bot

from rasa_core.agent import Agent
agent = Agent.load('models/dialogue', interpreter=model_directory)
# Out:
# WARNING:rasa_core.agent:Passing a value for interpreter to an agent where the value is not an interpreter is deprecated. Construct the interpreter, beforepassing it to the agent, e.g. `interpreter = NaturalLanguageInterpreter.create(nlu)`.
# INFO:tensorflow:Restoring parameters from /Users/saching12/Desktop/python codes/student_assistant_chatbot/./models/nlu/default/current/intent_classifier_tensorflow_embedding.ckpt
# INFO:tensorflow:Restoring parameters from /Users/saching12/Desktop/python codes/student_assistant_chatbot/./models/nlu/default/current/intent_classifier_tensorflow_embedding.ckpt

# %%
print("Your bot is ready to talk! Type your messages here or send 'stop'")
while True:
    a = input()
    if a == 'stop':
        break
    responses = agent.handle_text(a)
    for response in responses:
        print(response["text"])
# Out:
# Your bot is ready to talk! Type your messages here or send 'stop'
# is there any event tomorrow?
# ERROR:rasa_core.processor:Encountered an exception while running action 'action_retrieve_event'. Bot will continue, but the actions events are lost. Make sure to fix the exception in your custom code.
# Did that help you?
# no
# My bad I din't get you!!! Is there anything else you would like to ask ?.
# is there any event tomorrow?
# ERROR:rasa_core.processor:Encountered an exception while running action 'action_retrieve_event'. Bot will continue, but the actions events are lost. Make sure to fix the exception in your custom code.
# Did that help you?
# exit
# My bad I din't get you!!! Is there anything else you would like to ask ?.
